# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os
import cv2
import numpy as np

# %%
# Define the threshold value for blur detection
BLUR_THRESHOLD = 100

# Define the list of image file extensions to consider
IMAGE_EXTENSIONS = [".jpg", ".jpeg", ".png"]

# %%
def is_image_blurred(image_path):
    """
    Checks if an image is blurred using Laplacian variance.
    Returns True if the image is blurred, False otherwise.
    """
    image = cv2.imread(image_path)
    if image is None:
        return False  # Skip if the image cannot be read

    gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    blur_var = cv2.Laplacian(gray, cv2.CV_64F).var()

    return blur_var < BLUR_THRESHOLD

# %%
def delete_bad_images(root_folder):
    """
    Deletes blurred and bad images within the specified root folder and its subfolders.
    """
    for root, dirs, files in os.walk(root_folder):
        # Check if the current directory has subdirectories
        if any(os.path.isdir(os.path.join(root, d)) for d in dirs):
            continue  # Skip if there are no subdirectories

        # Iterate through the files in the current directory
        for file in files:
            file_path = os.path.join(root, file)
            file_extension = os.path.splitext(file_path)[1].lower()

            # Check if the file is an image
            if file_extension in IMAGE_EXTENSIONS:
                if is_image_blurred(file_path):
                    print(f"Deleting blurred image: {file_path}")
                    os.remove(file_path)

# %%
# Specify the root folder where the images are located
root_folder = "./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/"

# %%
# Call the function to delete bad images
delete_bad_images(root_folder)
# Out:
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Apium graveolens (Celery)/20200728_113321.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Apium graveolens (Celery)/20200728_113401.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Apium graveolens (Celery)/20200728_113216.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Apium graveolens (Celery)/20200728_113255.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Apium graveolens (Celery)/20200728_113458.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Apium graveolens (Celery)/20200728_113645.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Apium graveolens (Celery)/20200728_113621.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Apium graveolens (Celery)/20200728_113540.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Apium graveolens (Celery)/20200728_113654.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Apium graveolens (Celery)/20200728_113409.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Apium graveolens (Celery)/20200728_113517.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Apium graveolens (Celery)/20200728_113605.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Apium graveolens (Celery)/20200728_113820.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Apium graveolens (Celery)/20200728_113739.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Apium graveolens (Celery)/20200728_113856.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Apium graveolens (Celery)/20200728_113720.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Apium graveolens (Celery)/20200728_113728.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Apium graveolens (Celery)/20200728_113831.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Apium graveolens (Celery)/20200728_113809.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Apium graveolens (Celery)/20200728_114404.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Apium graveolens (Celery)/20200728_114221.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Apium graveolens (Celery)/20200728_114708.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Apium graveolens (Celery)/20200728_114346.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Apium graveolens (Celery)/20200728_114649.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Apium graveolens (Celery)/20200728_114305.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Apium graveolens (Celery)/20200728_114252.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Apium graveolens (Celery)/20200728_114148.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Apium graveolens (Celery)/20200728_114637.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Apium graveolens (Celery)/20200728_113914.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Apium graveolens (Celery)/20200728_114138.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Apium graveolens (Celery)/20200728_114629.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Apium graveolens (Celery)/20200728_114116.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Apium graveolens (Celery)/20200728_114107.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Apium graveolens (Celery)/20200728_114744.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Apium graveolens (Celery)/20200728_114917.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Apium graveolens (Celery)/20200728_114808.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Apium graveolens (Celery)/20200728_114837.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Apium graveolens (Celery)/20200728_114826.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Apium graveolens (Celery)/20200728_114716.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Apium graveolens (Celery)/20200728_114815.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Apium graveolens (Celery)/20200728_114924.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Apium graveolens (Celery)/20200728_114753.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Apium graveolens (Celery)/20200728_114852.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Apium graveolens (Celery)/20200728_114902.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Apium graveolens (Celery)/20200728_114950.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Apium graveolens (Celery)/20200728_114942.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Amaranthus dubius (Chinese Spinach)/20200413_084529.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Amaranthus dubius (Chinese Spinach)/20200413_084516.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Amaranthus dubius (Chinese Spinach)/20200413_084224.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Amaranthus dubius (Chinese Spinach)/20200413_084539.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Amaranthus dubius (Chinese Spinach)/20200413_084559.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Amaranthus dubius (Chinese Spinach)/20200413_084533.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Amaranthus dubius (Chinese Spinach)/20200413_084504.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Amaranthus dubius (Chinese Spinach)/20200413_084547.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Amaranthus dubius (Chinese Spinach)/20200413_084912.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Amaranthus dubius (Chinese Spinach)/20200413_084713.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Amaranthus dubius (Chinese Spinach)/20200413_084828.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Amaranthus dubius (Chinese Spinach)/20200413_084933.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Amaranthus dubius (Chinese Spinach)/20200413_084813.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Amaranthus dubius (Chinese Spinach)/20200413_084836.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Amaranthus dubius (Chinese Spinach)/20200413_084858.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Amaranthus dubius (Chinese Spinach)/20200413_084637.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Amaranthus dubius (Chinese Spinach)/20200413_084852.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Amaranthus dubius (Chinese Spinach)/20200413_084700.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Amaranthus dubius (Chinese Spinach)/20200413_084623.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Amaranthus dubius (Chinese Spinach)/20200413_085220.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Amaranthus dubius (Chinese Spinach)/20200413_084944.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Amaranthus dubius (Chinese Spinach)/20200413_085153.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Amaranthus dubius (Chinese Spinach)/20200413_085001.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Tridax procumbens (coatbuttons)/049_38.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Tridax procumbens (coatbuttons)/049_48.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Tridax procumbens (coatbuttons)/049_42.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Tridax procumbens (coatbuttons)/049_47.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Tridax procumbens (coatbuttons)/049_50.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Tridax procumbens (coatbuttons)/049_1.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Tridax procumbens (coatbuttons)/049_46.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Tridax procumbens (coatbuttons)/049_49.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Tridax procumbens (coatbuttons)/049_45.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Tridax procumbens (coatbuttons)/049_16.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Tridax procumbens (coatbuttons)/049_43.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Tridax procumbens (coatbuttons)/049_52.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Tridax procumbens (coatbuttons)/049_51.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Tridax procumbens (coatbuttons)/049_53.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Tridax procumbens (coatbuttons)/049_21.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Tridax procumbens (coatbuttons)/049_44.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Tridax procumbens (coatbuttons)/049_58.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Tridax procumbens (coatbuttons)/049_8.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Tridax procumbens (coatbuttons)/049_57.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Tridax procumbens (coatbuttons)/049_56.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Tridax procumbens (coatbuttons)/049_59.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Tridax procumbens (coatbuttons)/049_55.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Euphorbia hirta (Asthma Plant)/001_10.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Euphorbia hirta (Asthma Plant)/001_1.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Euphorbia hirta (Asthma Plant)/001_0.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Euphorbia hirta (Asthma Plant)/001_13.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Euphorbia hirta (Asthma Plant)/001_12.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Euphorbia hirta (Asthma Plant)/001_11.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Euphorbia hirta (Asthma Plant)/001_22.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Euphorbia hirta (Asthma Plant)/001_45.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Euphorbia hirta (Asthma Plant)/001_38.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Euphorbia hirta (Asthma Plant)/001_59.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Euphorbia hirta (Asthma Plant)/001_80.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Euphorbia hirta (Asthma Plant)/001_68.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Euphorbia hirta (Asthma Plant)/001_34.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Euphorbia hirta (Asthma Plant)/001_75.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Euphorbia hirta (Asthma Plant)/001_55.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Euphorbia hirta (Asthma Plant)/001_9.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Euphorbia hirta (Asthma Plant)/001_63.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Euphorbia hirta (Asthma Plant)/001_43.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Euphorbia hirta (Asthma Plant)/001_39.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Euphorbia hirta (Asthma Plant)/001_2.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Euphorbia hirta (Asthma Plant)/001_64.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Euphorbia hirta (Asthma Plant)/001_61.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Euphorbia hirta (Asthma Plant)/001_19.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Euphorbia hirta (Asthma Plant)/001_6.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Euphorbia hirta (Asthma Plant)/001_42.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Euphorbia hirta (Asthma Plant)/001_47.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Euphorbia hirta (Asthma Plant)/001_16.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Euphorbia hirta (Asthma Plant)/001_18.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Euphorbia hirta (Asthma Plant)/001_53.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Euphorbia hirta (Asthma Plant)/001_78.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Euphorbia hirta (Asthma Plant)/001_32.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Euphorbia hirta (Asthma Plant)/001_35.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Euphorbia hirta (Asthma Plant)/001_14.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Euphorbia hirta (Asthma Plant)/001_70.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Euphorbia hirta (Asthma Plant)/001_26.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Euphorbia hirta (Asthma Plant)/001_67.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Euphorbia hirta (Asthma Plant)/001_20.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Euphorbia hirta (Asthma Plant)/001_74.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Euphorbia hirta (Asthma Plant)/001_24.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Euphorbia hirta (Asthma Plant)/001_76.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Euphorbia hirta (Asthma Plant)/001_65.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Euphorbia hirta (Asthma Plant)/001_33.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Euphorbia hirta (Asthma Plant)/001_28.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Euphorbia hirta (Asthma Plant)/001_69.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Euphorbia hirta (Asthma Plant)/001_50.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Euphorbia hirta (Asthma Plant)/001_37.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Euphorbia hirta (Asthma Plant)/001_62.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Euphorbia hirta (Asthma Plant)/001_52.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Euphorbia hirta (Asthma Plant)/001_40.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Euphorbia hirta (Asthma Plant)/001_5.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Euphorbia hirta (Asthma Plant)/001_21.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Euphorbia hirta (Asthma Plant)/001_79.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Euphorbia hirta (Asthma Plant)/001_17.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Euphorbia hirta (Asthma Plant)/001_46.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Euphorbia hirta (Asthma Plant)/001_41.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Euphorbia hirta (Asthma Plant)/001_4.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Euphorbia hirta (Asthma Plant)/001_51.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Euphorbia hirta (Asthma Plant)/001_48.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Euphorbia hirta (Asthma Plant)/001_66.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Euphorbia hirta (Asthma Plant)/001_77.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Euphorbia hirta (Asthma Plant)/001_56.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Euphorbia hirta (Asthma Plant)/001_25.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Euphorbia hirta (Asthma Plant)/001_60.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Euphorbia hirta (Asthma Plant)/001_73.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Euphorbia hirta (Asthma Plant)/001_7.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Euphorbia hirta (Asthma Plant)/001_23.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Euphorbia hirta (Asthma Plant)/001_57.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Euphorbia hirta (Asthma Plant)/001_3.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Euphorbia hirta (Asthma Plant)/001_72.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Euphorbia hirta (Asthma Plant)/001_30.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Euphorbia hirta (Asthma Plant)/001_29.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Euphorbia hirta (Asthma Plant)/001_54.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Euphorbia hirta (Asthma Plant)/001_44.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Euphorbia hirta (Asthma Plant)/001_49.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Euphorbia hirta (Asthma Plant)/001_15.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Euphorbia hirta (Asthma Plant)/001_36.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Euphorbia hirta (Asthma Plant)/001_27.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Euphorbia hirta (Asthma Plant)/001_31.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Euphorbia hirta (Asthma Plant)/001_71.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Euphorbia hirta (Asthma Plant)/001_8.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Euphorbia hirta (Asthma Plant)/001_58.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Sida acuta (Common Wireweed)/011_3.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Sida acuta (Common Wireweed)/011_20.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Sida acuta (Common Wireweed)/011_14.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Sida acuta (Common Wireweed)/011_29.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Sida acuta (Common Wireweed)/011_30.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Sida acuta (Common Wireweed)/011_26.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Sida acuta (Common Wireweed)/011_25.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Sida acuta (Common Wireweed)/011_1.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Sida acuta (Common Wireweed)/011_2.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Sida acuta (Common Wireweed)/011_10.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Sida acuta (Common Wireweed)/011_24.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Sida acuta (Common Wireweed)/011_23.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Sida acuta (Common Wireweed)/011_31.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Sida acuta (Common Wireweed)/011_32.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Sida acuta (Common Wireweed)/011_19.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Sida acuta (Common Wireweed)/011_18.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Sida acuta (Common Wireweed)/011_12.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Sida acuta (Common Wireweed)/011_11.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Sida acuta (Common Wireweed)/011_15.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Sida acuta (Common Wireweed)/011_17.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Sida acuta (Common Wireweed)/011_28.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Sida acuta (Common Wireweed)/011_21.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Sida acuta (Common Wireweed)/011_0.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Sida acuta (Common Wireweed)/011_27.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Sida acuta (Common Wireweed)/011_13.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Sida acuta (Common Wireweed)/011_16.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Sida acuta (Common Wireweed)/011_8.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Sida acuta (Common Wireweed)/011_55.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Sida acuta (Common Wireweed)/011_56.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Sida acuta (Common Wireweed)/011_9.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Sida acuta (Common Wireweed)/011_38.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Sida acuta (Common Wireweed)/011_49.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Sida acuta (Common Wireweed)/011_4.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Sida acuta (Common Wireweed)/011_46.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Sida acuta (Common Wireweed)/011_33.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Sida acuta (Common Wireweed)/011_36.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Sida acuta (Common Wireweed)/011_7.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Sida acuta (Common Wireweed)/011_40.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Sida acuta (Common Wireweed)/011_35.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Sida acuta (Common Wireweed)/011_37.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Sida acuta (Common Wireweed)/011_52.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Sida acuta (Common Wireweed)/011_59.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Sida acuta (Common Wireweed)/011_6.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Sida acuta (Common Wireweed)/011_34.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Sida acuta (Common Wireweed)/011_42.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Sida acuta (Common Wireweed)/011_54.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Sida acuta (Common Wireweed)/011_41.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Sida acuta (Common Wireweed)/011_51.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Sida acuta (Common Wireweed)/011_43.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Sida acuta (Common Wireweed)/011_45.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Sida acuta (Common Wireweed)/011_53.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Sida acuta (Common Wireweed)/011_47.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Sida acuta (Common Wireweed)/011_5.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Sida acuta (Common Wireweed)/011_39.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Sida acuta (Common Wireweed)/011_57.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Sida acuta (Common Wireweed)/011_58.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Coriandrum sativum (Coriander Leaves)/20200223_084621.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Coriandrum sativum (Coriander Leaves)/20200223_084359.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Coriandrum sativum (Coriander Leaves)/20200223_084456.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Coriandrum sativum (Coriander Leaves)/20200223_084613.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Coriandrum sativum (Coriander Leaves)/20200223_084459.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Coriandrum sativum (Coriander Leaves)/20200223_084603.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Coriandrum sativum (Coriander Leaves)/20200223_084318.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Coriandrum sativum (Coriander Leaves)/20200223_084630.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Coriandrum sativum (Coriander Leaves)/20200223_084223.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Coriandrum sativum (Coriander Leaves)/20200223_084502.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Coriandrum sativum (Coriander Leaves)/20200223_084402.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Coriandrum sativum (Coriander Leaves)/20200223_084443.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Coriandrum sativum (Coriander Leaves)/20200223_084406.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Coriandrum sativum (Coriander Leaves)/20200223_084425.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Coriandrum sativum (Coriander Leaves)/20200223_084411.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Coriandrum sativum (Coriander Leaves)/20200223_084420.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Coriandrum sativum (Coriander Leaves)/20200223_084518.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Coriandrum sativum (Coriander Leaves)/20200223_084416.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Coriandrum sativum (Coriander Leaves)/20200223_084541.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Coriandrum sativum (Coriander Leaves)/20200223_084636.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Coriandrum sativum (Coriander Leaves)/20200223_084626.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Coriandrum sativum (Coriander Leaves)/20200223_084236.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Coriandrum sativum (Coriander Leaves)/20200223_084439.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Coriandrum sativum (Coriander Leaves)/20200223_084228.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Coriandrum sativum (Coriander Leaves)/20200223_084422.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Coriandrum sativum (Coriander Leaves)/20200223_084609.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Coriandrum sativum (Coriander Leaves)/20200223_084427.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Coriandrum sativum (Coriander Leaves)/20200223_085116.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Coriandrum sativum (Coriander Leaves)/20200223_084848.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Coriandrum sativum (Coriander Leaves)/20200223_084910.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Coriandrum sativum (Coriander Leaves)/20200223_084959.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Coriandrum sativum (Coriander Leaves)/20200223_084703.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Coriandrum sativum (Coriander Leaves)/20200223_084844.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Coriandrum sativum (Coriander Leaves)/20200223_084952.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Coriandrum sativum (Coriander Leaves)/20200223_085012.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Coriandrum sativum (Coriander Leaves)/20200223_085009.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Coriandrum sativum (Coriander Leaves)/20200223_084707.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Coriandrum sativum (Coriander Leaves)/20200223_084855.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Coriandrum sativum (Coriander Leaves)/20200223_084745.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Coriandrum sativum (Coriander Leaves)/20200223_084734.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Coriandrum sativum (Coriander Leaves)/20200223_085200.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Coriandrum sativum (Coriander Leaves)/20200223_084942.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Coriandrum sativum (Coriander Leaves)/20200223_085046.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Coriandrum sativum (Coriander Leaves)/20200223_085016.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Coriandrum sativum (Coriander Leaves)/20200223_084723.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Coriandrum sativum (Coriander Leaves)/20200223_084842.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Coriandrum sativum (Coriander Leaves)/20200223_085004.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Coriandrum sativum (Coriander Leaves)/20200223_085101.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Coriandrum sativum (Coriander Leaves)/20200223_084834.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Coriandrum sativum (Coriander Leaves)/20200223_085034.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Coriandrum sativum (Coriander Leaves)/20200223_084818.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Coriandrum sativum (Coriander Leaves)/20200223_085125.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Coriandrum sativum (Coriander Leaves)/20200223_085119.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Coriandrum sativum (Coriander Leaves)/20200223_085021.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Coriandrum sativum (Coriander Leaves)/20200223_084954.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Coriandrum sativum (Coriander Leaves)/20200223_084807.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Coriandrum sativum (Coriander Leaves)/20200223_085028.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Coriandrum sativum (Coriander Leaves)/20200223_084839.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Coriandrum sativum (Coriander Leaves)/20200223_085049.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Coriandrum sativum (Coriander Leaves)/20200223_084644.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Coriandrum sativum (Coriander Leaves)/20200223_084853.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Coriandrum sativum (Coriander Leaves)/20200223_084858.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Coriandrum sativum (Coriander Leaves)/20200223_084739.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Coriandrum sativum (Coriander Leaves)/20200409_130044.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Coriandrum sativum (Coriander Leaves)/20200223_085001.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Coriandrum sativum (Coriander Leaves)/20200223_084640.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Coriandrum sativum (Coriander Leaves)/20200223_084940.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Coriandrum sativum (Coriander Leaves)/20200409_130052.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Coriandrum sativum (Coriander Leaves)/20200223_085107.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Coriandrum sativum (Coriander Leaves)/20200223_084728.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Coriandrum sativum (Coriander Leaves)/20200223_084907.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Coriandrum sativum (Coriander Leaves)/20200223_084902.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Coriandrum sativum (Coriander Leaves)/20200409_130512.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Coriandrum sativum (Coriander Leaves)/20200409_130257.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Coriandrum sativum (Coriander Leaves)/20200409_130811.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Coriandrum sativum (Coriander Leaves)/20200409_130118.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Coriandrum sativum (Coriander Leaves)/20200409_130706.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Coriandrum sativum (Coriander Leaves)/20200409_130441.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Coriandrum sativum (Coriander Leaves)/20200409_130928.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Coriandrum sativum (Coriander Leaves)/20200409_130328.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Coriandrum sativum (Coriander Leaves)/20200409_130822.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Coriandrum sativum (Coriander Leaves)/20200409_130658.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Coriandrum sativum (Coriander Leaves)/20200409_130942.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Coriandrum sativum (Coriander Leaves)/20200409_130241.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Coriandrum sativum (Coriander Leaves)/20200409_130208.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Coriandrum sativum (Coriander Leaves)/20200409_130715.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Coriandrum sativum (Coriander Leaves)/20200409_130453.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Coriandrum sativum (Coriander Leaves)/20200409_130311.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Coriandrum sativum (Coriander Leaves)/20200409_130629.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Coriandrum sativum (Coriander Leaves)/20200409_130427.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Coriandrum sativum (Coriander Leaves)/20200409_130133.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Coriandrum sativum (Coriander Leaves)/20200409_130521.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Coriandrum sativum (Coriander Leaves)/20200409_130651.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Coriandrum sativum (Coriander Leaves)/20200409_130219.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Coriandrum sativum (Coriander Leaves)/20200409_130724.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Coriandrum sativum (Coriander Leaves)/20200409_130410.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Coriandrum sativum (Coriander Leaves)/20200409_131029.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Coriandrum sativum (Coriander Leaves)/20200409_130802.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Coriandrum sativum (Coriander Leaves)/20200409_130354.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Coriandrum sativum (Coriander Leaves)/20200409_130844.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Coriandrum sativum (Coriander Leaves)/20200409_130342.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Coriandrum sativum (Coriander Leaves)/20200409_132546.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Coriandrum sativum (Coriander Leaves)/20200409_131048.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Coriandrum sativum (Coriander Leaves)/20200409_131129.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Coriandrum sativum (Coriander Leaves)/20200409_131146.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Coriandrum sativum (Coriander Leaves)/20200409_131339.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Coriandrum sativum (Coriander Leaves)/20200409_131440.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Coriandrum sativum (Coriander Leaves)/20200409_131252.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Coriandrum sativum (Coriander Leaves)/20200409_131407.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Coriandrum sativum (Coriander Leaves)/20200409_132608.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Coriandrum sativum (Coriander Leaves)/20200409_131315.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Coriandrum sativum (Coriander Leaves)/20200409_131140.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Coriandrum sativum (Coriander Leaves)/20200409_131418.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Coriandrum sativum (Coriander Leaves)/20200409_131122.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Coriandrum sativum (Coriander Leaves)/20200409_131233.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Coriandrum sativum (Coriander Leaves)/20200409_132618.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Coriandrum sativum (Coriander Leaves)/20200409_131346.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Coriandrum sativum (Coriander Leaves)/20200409_131106.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Coriandrum sativum (Coriander Leaves)/20200409_131037.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Calotropis gigantea (Crown flower)/013_30.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Calotropis gigantea (Crown flower)/013_5.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Calotropis gigantea (Crown flower)/013_50.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Sida cordifolia (Country Mallow)/012_21.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Sida cordifolia (Country Mallow)/012_23.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Sida cordifolia (Country Mallow)/012_20.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Sida cordifolia (Country Mallow)/012_56.jpg
# ...
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Anisomeles indica (Malabar Catmint)/027_2.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Anisomeles indica (Malabar Catmint)/027_16.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Anisomeles indica (Malabar Catmint)/027_43.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Anisomeles indica (Malabar Catmint)/027_24.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Anisomeles indica (Malabar Catmint)/027_36.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Anisomeles indica (Malabar Catmint)/027_19.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Anisomeles indica (Malabar Catmint)/027_29.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Anisomeles indica (Malabar Catmint)/027_51.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Anisomeles indica (Malabar Catmint)/027_48.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Anisomeles indica (Malabar Catmint)/027_15.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Anisomeles indica (Malabar Catmint)/027_3.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Anisomeles indica (Malabar Catmint)/027_61.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Anisomeles indica (Malabar Catmint)/027_8.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Anisomeles indica (Malabar Catmint)/027_7.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Anisomeles indica (Malabar Catmint)/027_63.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Anisomeles indica (Malabar Catmint)/027_60.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Anisomeles indica (Malabar Catmint)/027_9.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Anisomeles indica (Malabar Catmint)/027_62.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Anisomeles indica (Malabar Catmint)/027_6.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Cucumis maderaspatanus (Madras Pea Pumpkin)/026_21.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Cucumis maderaspatanus (Madras Pea Pumpkin)/026_15.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Cucumis maderaspatanus (Madras Pea Pumpkin)/026_28.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Cucumis maderaspatanus (Madras Pea Pumpkin)/026_26.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Cucumis maderaspatanus (Madras Pea Pumpkin)/026_18.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Cucumis maderaspatanus (Madras Pea Pumpkin)/026_51.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Cucumis maderaspatanus (Madras Pea Pumpkin)/026_45.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Cucumis maderaspatanus (Madras Pea Pumpkin)/026_50.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Cucumis maderaspatanus (Madras Pea Pumpkin)/026_37.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Cucumis maderaspatanus (Madras Pea Pumpkin)/026_38.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Cucumis maderaspatanus (Madras Pea Pumpkin)/026_43.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Cucumis maderaspatanus (Madras Pea Pumpkin)/026_40.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Cucumis maderaspatanus (Madras Pea Pumpkin)/026_4.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Cucumis maderaspatanus (Madras Pea Pumpkin)/026_48.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Cucumis maderaspatanus (Madras Pea Pumpkin)/026_52.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Catharanthus roseus (Madagascar Periwinkle)/025_11.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Catharanthus roseus (Madagascar Periwinkle)/025_44.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Catharanthus roseus (Madagascar Periwinkle)/025_12.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Catharanthus roseus (Madagascar Periwinkle)/025_8.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Catharanthus roseus (Madagascar Periwinkle)/025_19.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Catharanthus roseus (Madagascar Periwinkle)/025_23.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Catharanthus roseus (Madagascar Periwinkle)/025_6.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Catharanthus roseus (Madagascar Periwinkle)/025_4.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Catharanthus roseus (Madagascar Periwinkle)/025_21.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Catharanthus roseus (Madagascar Periwinkle)/025_13.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Catharanthus roseus (Madagascar Periwinkle)/025_40.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Catharanthus roseus (Madagascar Periwinkle)/025_52.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Catharanthus roseus (Madagascar Periwinkle)/025_26.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Catharanthus roseus (Madagascar Periwinkle)/025_31.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Catharanthus roseus (Madagascar Periwinkle)/025_14.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Catharanthus roseus (Madagascar Periwinkle)/025_46.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Catharanthus roseus (Madagascar Periwinkle)/025_38.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Catharanthus roseus (Madagascar Periwinkle)/025_36.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Catharanthus roseus (Madagascar Periwinkle)/025_29.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Pisonia umbellifera (Lettuce Tree)/20200625_105954.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Pisonia umbellifera (Lettuce Tree)/20200625_110103.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Pisonia umbellifera (Lettuce Tree)/20200625_110142.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Pisonia umbellifera (Lettuce Tree)/20200625_110116.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Pisonia umbellifera (Lettuce Tree)/20200625_110231.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Pisonia umbellifera (Lettuce Tree)/20200625_110218.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Pisonia umbellifera (Lettuce Tree)/20200625_110155.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Pisonia umbellifera (Lettuce Tree)/20200625_110259.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Land Caltrops (Bindii)/024_40.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Land Caltrops (Bindii)/024_8.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Land Caltrops (Bindii)/024_35.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Land Caltrops (Bindii)/024_18.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Land Caltrops (Bindii)/024_33.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Land Caltrops (Bindii)/024_55.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Land Caltrops (Bindii)/024_61.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Land Caltrops (Bindii)/024_15.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Land Caltrops (Bindii)/024_29.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Land Caltrops (Bindii)/024_13.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Land Caltrops (Bindii)/024_62.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Land Caltrops (Bindii)/024_52.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Land Caltrops (Bindii)/024_11.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Land Caltrops (Bindii)/024_49.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Land Caltrops (Bindii)/024_17.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Land Caltrops (Bindii)/024_44.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Land Caltrops (Bindii)/024_54.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Land Caltrops (Bindii)/024_56.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Land Caltrops (Bindii)/024_31.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Land Caltrops (Bindii)/024_22.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Land Caltrops (Bindii)/024_41.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Land Caltrops (Bindii)/024_60.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Land Caltrops (Bindii)/024_26.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Land Caltrops (Bindii)/024_19.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Land Caltrops (Bindii)/024_30.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Land Caltrops (Bindii)/024_24.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Land Caltrops (Bindii)/024_48.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Land Caltrops (Bindii)/024_45.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Land Caltrops (Bindii)/024_36.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Land Caltrops (Bindii)/024_14.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Land Caltrops (Bindii)/024_42.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Land Caltrops (Bindii)/024_21.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Land Caltrops (Bindii)/024_23.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Land Caltrops (Bindii)/024_7.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Land Caltrops (Bindii)/024_57.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Land Caltrops (Bindii)/024_46.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Land Caltrops (Bindii)/024_58.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Land Caltrops (Bindii)/024_59.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Land Caltrops (Bindii)/024_53.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Land Caltrops (Bindii)/024_50.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Land Caltrops (Bindii)/024_5.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Land Caltrops (Bindii)/024_4.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Land Caltrops (Bindii)/024_28.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Land Caltrops (Bindii)/024_38.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Land Caltrops (Bindii)/024_16.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Land Caltrops (Bindii)/024_34.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Land Caltrops (Bindii)/024_37.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Land Caltrops (Bindii)/024_51.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Land Caltrops (Bindii)/024_39.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Land Caltrops (Bindii)/024_6.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Land Caltrops (Bindii)/024_32.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Land Caltrops (Bindii)/024_9.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Land Caltrops (Bindii)/024_1.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Land Caltrops (Bindii)/024_43.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Land Caltrops (Bindii)/024_12.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Land Caltrops (Bindii)/024_2.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Land Caltrops (Bindii)/024_47.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Land Caltrops (Bindii)/024_10.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Land Caltrops (Bindii)/024_27.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Land Caltrops (Bindii)/024_3.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Land Caltrops (Bindii)/024_25.jpg
# Deleting blurred image: ./drive/MyDrive/final_year_project/Datasets/MepcoTropicLeaf-V1/Land Caltrops (Bindii)/024_20.jpg

# %%
def rename_images(directory):
    for root, dirs, files in os.walk(directory):
        file_count = 1
        for file_name in files:
            if file_name.endswith('.jpg') or file_name.endswith('.png'):
                a = os.path.basename(root).split(' ')
                new_file_name = None
                if (len(a) > 2):
                  genus = a[0]
                  species = a[1]
                  print(a)
                  new_file_name = f"{genus[0].capitalize()}{species[0].capitalize()}-S-{file_count:03d}"
                if (len(a) == 2):
                  genus = a[0]
                  print(a)
                  new_file_name = f"{genus[0].capitalize()}-S-{file_count:03d}"

                file_count += 1
                old_file_path = os.path.join(root, file_name)
                new_file_path = os.path.join(root, new_file_name + os.path.splitext(file_name)[1])
                os.rename(old_file_path, new_file_path)

# %%
rename_images(root_folder)
# Out:
# ['Boerhavia', 'diffusa', '(Punarnava)']
# ['Boerhavia', 'diffusa', '(Punarnava)']
# ['Boerhavia', 'diffusa', '(Punarnava)']
# ['Boerhavia', 'diffusa', '(Punarnava)']
# ['Boerhavia', 'diffusa', '(Punarnava)']
# ['Boerhavia', 'diffusa', '(Punarnava)']
# ['Boerhavia', 'diffusa', '(Punarnava)']
# ['Boerhavia', 'diffusa', '(Punarnava)']
# ['Boerhavia', 'diffusa', '(Punarnava)']
# ['Boerhavia', 'diffusa', '(Punarnava)']
# ['Boerhavia', 'diffusa', '(Punarnava)']
# ['Boerhavia', 'diffusa', '(Punarnava)']
# ['Boerhavia', 'diffusa', '(Punarnava)']
# ['Boerhavia', 'diffusa', '(Punarnava)']
# ['Boerhavia', 'diffusa', '(Punarnava)']
# ['Boerhavia', 'diffusa', '(Punarnava)']
# ['Boerhavia', 'diffusa', '(Punarnava)']
# ['Boerhavia', 'diffusa', '(Punarnava)']
# ['Boerhavia', 'diffusa', '(Punarnava)']
# ['Boerhavia', 'diffusa', '(Punarnava)']
# ['Boerhavia', 'diffusa', '(Punarnava)']
# ['Boerhavia', 'diffusa', '(Punarnava)']
# ['Boerhavia', 'diffusa', '(Punarnava)']
# ['Dwarf', 'copperleaf', '(Red)']
# ['Dwarf', 'copperleaf', '(Red)']
# ['Dwarf', 'Copperleaf', '(Green)']
# ['Dwarf', 'Copperleaf', '(Green)']
# ['Dwarf', 'Copperleaf', '(Green)']
# ['Dwarf', 'Copperleaf', '(Green)']
# ['Dwarf', 'Copperleaf', '(Green)']
# ['Dwarf', 'Copperleaf', '(Green)']
# ['Dwarf', 'Copperleaf', '(Green)']
# ['Dwarf', 'Copperleaf', '(Green)']
# ['Dwarf', 'Copperleaf', '(Green)']
# ['Dwarf', 'Copperleaf', '(Green)']
# ['Dwarf', 'Copperleaf', '(Green)']
# ['Dwarf', 'Copperleaf', '(Green)']
# ['Dwarf', 'Copperleaf', '(Green)']
# ['Dwarf', 'Copperleaf', '(Green)']
# ['Dwarf', 'Copperleaf', '(Green)']
# ['Dwarf', 'Copperleaf', '(Green)']
# ['Dwarf', 'Copperleaf', '(Green)']
# ['Dwarf', 'Copperleaf', '(Green)']
# ['Dwarf', 'Copperleaf', '(Green)']
# ['Dwarf', 'Copperleaf', '(Green)']
# ['Dwarf', 'Copperleaf', '(Green)']
# ['Dwarf', 'Copperleaf', '(Green)']
# ['Dwarf', 'Copperleaf', '(Green)']
# ['Dwarf', 'Copperleaf', '(Green)']
# ['Ipomoea', 'aquatica', '(Water', 'Spinach)']
# ['Ipomoea', 'aquatica', '(Water', 'Spinach)']
# ['Ipomoea', 'aquatica', '(Water', 'Spinach)']
# ['Ipomoea', 'aquatica', '(Water', 'Spinach)']
# ['Ipomoea', 'aquatica', '(Water', 'Spinach)']
# ['Ipomoea', 'aquatica', '(Water', 'Spinach)']
# ['Ipomoea', 'aquatica', '(Water', 'Spinach)']
# ['Ipomoea', 'aquatica', '(Water', 'Spinach)']
# ['Ipomoea', 'aquatica', '(Water', 'Spinach)']
# ['Ipomoea', 'aquatica', '(Water', 'Spinach)']
# ['Ipomoea', 'aquatica', '(Water', 'Spinach)']
# ['Ipomoea', 'aquatica', '(Water', 'Spinach)']
# ['Ipomoea', 'aquatica', '(Water', 'Spinach)']
# ['Ipomoea', 'aquatica', '(Water', 'Spinach)']
# ['Ipomoea', 'aquatica', '(Water', 'Spinach)']
# ['Ipomoea', 'aquatica', '(Water', 'Spinach)']
# ['Ipomoea', 'aquatica', '(Water', 'Spinach)']
# ['Mucuna', 'pruriens', '(Velvet', 'bean)']
# ['Mucuna', 'pruriens', '(Velvet', 'bean)']
# ['Mucuna', 'pruriens', '(Velvet', 'bean)']
# ['Mucuna', 'pruriens', '(Velvet', 'bean)']
# ['Mucuna', 'pruriens', '(Velvet', 'bean)']
# ['Mucuna', 'pruriens', '(Velvet', 'bean)']
# ['Mucuna', 'pruriens', '(Velvet', 'bean)']
# ['Mucuna', 'pruriens', '(Velvet', 'bean)']
# ['Mucuna', 'pruriens', '(Velvet', 'bean)']
# ['Mucuna', 'pruriens', '(Velvet', 'bean)']
# ['Mucuna', 'pruriens', '(Velvet', 'bean)']
# ['Mucuna', 'pruriens', '(Velvet', 'bean)']
# ['Mucuna', 'pruriens', '(Velvet', 'bean)']
# ['Mucuna', 'pruriens', '(Velvet', 'bean)']
# ['Mucuna', 'pruriens', '(Velvet', 'bean)']
# ['Mucuna', 'pruriens', '(Velvet', 'bean)']
# ['Mucuna', 'pruriens', '(Velvet', 'bean)']
# ['Mucuna', 'pruriens', '(Velvet', 'bean)']
# ['Mucuna', 'pruriens', '(Velvet', 'bean)']
# ['Mucuna', 'pruriens', '(Velvet', 'bean)']
# ['Mucuna', 'pruriens', '(Velvet', 'bean)']
# ['Mucuna', 'pruriens', '(Velvet', 'bean)']
# ['Mucuna', 'pruriens', '(Velvet', 'bean)']
# ['Mucuna', 'pruriens', '(Velvet', 'bean)']
# ['Mucuna', 'pruriens', '(Velvet', 'bean)']
# ['Mucuna', 'pruriens', '(Velvet', 'bean)']
# ['Mucuna', 'pruriens', '(Velvet', 'bean)']
# ['Mucuna', 'pruriens', '(Velvet', 'bean)']
# ['Mucuna', 'pruriens', '(Velvet', 'bean)']
# ['Mucuna', 'pruriens', '(Velvet', 'bean)']
# ['Mucuna', 'pruriens', '(Velvet', 'bean)']
# ['Mucuna', 'pruriens', '(Velvet', 'bean)']
# ['Mucuna', 'pruriens', '(Velvet', 'bean)']
# ['Mucuna', 'pruriens', '(Velvet', 'bean)']
# ['Mucuna', 'pruriens', '(Velvet', 'bean)']
# ['Mucuna', 'pruriens', '(Velvet', 'bean)']
# ['Mucuna', 'pruriens', '(Velvet', 'bean)']
# ['Mucuna', 'pruriens', '(Velvet', 'bean)']
# ['Mucuna', 'pruriens', '(Velvet', 'bean)']
# ['Mucuna', 'pruriens', '(Velvet', 'bean)']
# ['Mucuna', 'pruriens', '(Velvet', 'bean)']
# ['Mucuna', 'pruriens', '(Velvet', 'bean)']
# ['Mucuna', 'pruriens', '(Velvet', 'bean)']
# ['Mucuna', 'pruriens', '(Velvet', 'bean)']
# ['Mucuna', 'pruriens', '(Velvet', 'bean)']
# ['Mucuna', 'pruriens', '(Velvet', 'bean)']
# ['Mucuna', 'pruriens', '(Velvet', 'bean)']
# ['Mucuna', 'pruriens', '(Velvet', 'bean)']
# ['Mucuna', 'pruriens', '(Velvet', 'bean)']
# ['Mucuna', 'pruriens', '(Velvet', 'bean)']
# ['Mucuna', 'pruriens', '(Velvet', 'bean)']
# ['Mucuna', 'pruriens', '(Velvet', 'bean)']
# ['Mucuna', 'pruriens', '(Velvet', 'bean)']
# ['Mucuna', 'pruriens', '(Velvet', 'bean)']
# ['Mucuna', 'pruriens', '(Velvet', 'bean)']
# ['Mucuna', 'pruriens', '(Velvet', 'bean)']
# ['Mucuna', 'pruriens', '(Velvet', 'bean)']
# ['Mucuna', 'pruriens', '(Velvet', 'bean)']
# ['Mucuna', 'pruriens', '(Velvet', 'bean)']
# ['Mucuna', 'pruriens', '(Velvet', 'bean)']
# ['Mucuna', 'pruriens', '(Velvet', 'bean)']
# ['Mucuna', 'pruriens', '(Velvet', 'bean)']
# ['Mucuna', 'pruriens', '(Velvet', 'bean)']
# ['Mucuna', 'pruriens', '(Velvet', 'bean)']
# ['Mucuna', 'pruriens', '(Velvet', 'bean)']
# ['Mucuna', 'pruriens', '(Velvet', 'bean)']
# ['Amaranthus', 'hybridus', '(Green', 'Amaranth)']
# ['Amaranthus', 'hybridus', '(Green', 'Amaranth)']
# ['Amaranthus', 'hybridus', '(Green', 'Amaranth)']
# ['Amaranthus', 'hybridus', '(Green', 'Amaranth)']
# ['Amaranthus', 'hybridus', '(Green', 'Amaranth)']
# ['Amaranthus', 'hybridus', '(Green', 'Amaranth)']
# ['Amaranthus', 'hybridus', '(Green', 'Amaranth)']
# ['Cardiospermum', 'halicacabum', '(Balloon', 'vine)', '(1)']
# ['Cardiospermum', 'halicacabum', '(Balloon', 'vine)', '(1)']
# ['Tribulus', 'terrestris', '(Big', 'Caltrops)']
# ['Tribulus', 'terrestris', '(Big', 'Caltrops)']
# ['Tribulus', 'terrestris', '(Big', 'Caltrops)']
# ['Tribulus', 'terrestris', '(Big', 'Caltrops)']
# ['Tribulus', 'terrestris', '(Big', 'Caltrops)']
# ['Tribulus', 'terrestris', '(Big', 'Caltrops)']
# ['Tribulus', 'terrestris', '(Big', 'Caltrops)']
# ['Tribulus', 'terrestris', '(Big', 'Caltrops)']
# ['Tribulus', 'terrestris', '(Big', 'Caltrops)']
# ['Tribulus', 'terrestris', '(Big', 'Caltrops)']
# ['Tribulus', 'terrestris', '(Big', 'Caltrops)']
# ['Tribulus', 'terrestris', '(Big', 'Caltrops)']
# ['Tribulus', 'terrestris', '(Big', 'Caltrops)']
# ['Tribulus', 'terrestris', '(Big', 'Caltrops)']
# ['Tribulus', 'terrestris', '(Big', 'Caltrops)']
# ['Tribulus', 'terrestris', '(Big', 'Caltrops)']
# ['Tribulus', 'terrestris', '(Big', 'Caltrops)']
# ['Tribulus', 'terrestris', '(Big', 'Caltrops)']
# ['Tribulus', 'terrestris', '(Big', 'Caltrops)']
# ['Tribulus', 'terrestris', '(Big', 'Caltrops)']
# ['Tribulus', 'terrestris', '(Big', 'Caltrops)']
# ['Tribulus', 'terrestris', '(Big', 'Caltrops)']
# ['Tribulus', 'terrestris', '(Big', 'Caltrops)']
# ['Tribulus', 'terrestris', '(Big', 'Caltrops)']
# ['Tribulus', 'terrestris', '(Big', 'Caltrops)']
# ['Tribulus', 'terrestris', '(Big', 'Caltrops)']
# ['Tribulus', 'terrestris', '(Big', 'Caltrops)']
# ['Tribulus', 'terrestris', '(Big', 'Caltrops)']
# ['Tribulus', 'terrestris', '(Big', 'Caltrops)']
# ['Tribulus', 'terrestris', '(Big', 'Caltrops)']
# ['Tribulus', 'terrestris', '(Big', 'Caltrops)']
# ['Tribulus', 'terrestris', '(Big', 'Caltrops)']
# ['Tribulus', 'terrestris', '(Big', 'Caltrops)']
# ['Tribulus', 'terrestris', '(Big', 'Caltrops)']
# ['Cardiospermum', 'halicacabum', '(Balloon', 'vine)']
# ['Cardiospermum', 'halicacabum', '(Balloon', 'vine)']
# ['Cardiospermum', 'halicacabum', '(Balloon', 'vine)']
# ['Cardiospermum', 'halicacabum', '(Balloon', 'vine)']
# ['Cardiospermum', 'halicacabum', '(Balloon', 'vine)']
# ['Cardiospermum', 'halicacabum', '(Balloon', 'vine)']
# ['Cardiospermum', 'halicacabum', '(Balloon', 'vine)']
# ['Cardiospermum', 'halicacabum', '(Balloon', 'vine)']
# ['Cardiospermum', 'halicacabum', '(Balloon', 'vine)']
# ['Cardiospermum', 'halicacabum', '(Balloon', 'vine)']
# ['Cardiospermum', 'halicacabum', '(Balloon', 'vine)']
# ['Cardiospermum', 'halicacabum', '(Balloon', 'vine)']
# ['Cardiospermum', 'halicacabum', '(Balloon', 'vine)']
# ['Cardiospermum', 'halicacabum', '(Balloon', 'vine)']
# ['Cardiospermum', 'halicacabum', '(Balloon', 'vine)']
# ['Cardiospermum', 'halicacabum', '(Balloon', 'vine)']
# ['Cardiospermum', 'halicacabum', '(Balloon', 'vine)']
# ['Cardiospermum', 'halicacabum', '(Balloon', 'vine)']
# ['Cardiospermum', 'halicacabum', '(Balloon', 'vine)']
# ['Cardiospermum', 'halicacabum', '(Balloon', 'vine)']
# ['Cardiospermum', 'halicacabum', '(Balloon', 'vine)']
# ['Cardiospermum', 'halicacabum', '(Balloon', 'vine)']
# ['Cardiospermum', 'halicacabum', '(Balloon', 'vine)']
# ['Cardiospermum', 'halicacabum', '(Balloon', 'vine)']
# ['Cardiospermum', 'halicacabum', '(Balloon', 'vine)']
# ['Cardiospermum', 'halicacabum', '(Balloon', 'vine)']
# ['Cardiospermum', 'halicacabum', '(Balloon', 'vine)']
# ['Cardiospermum', 'halicacabum', '(Balloon', 'vine)']
# ['Cardiospermum', 'halicacabum', '(Balloon', 'vine)']
# ['Cardiospermum', 'halicacabum', '(Balloon', 'vine)']
# ['Cardiospermum', 'halicacabum', '(Balloon', 'vine)']
# ['Cardiospermum', 'halicacabum', '(Balloon', 'vine)']
# ['Cardiospermum', 'halicacabum', '(Balloon', 'vine)']
# ['Cardiospermum', 'halicacabum', '(Balloon', 'vine)']
# ['Cardiospermum', 'halicacabum', '(Balloon', 'vine)']
# ['Cardiospermum', 'halicacabum', '(Balloon', 'vine)']
# ['Cardiospermum', 'halicacabum', '(Balloon', 'vine)']
# ['Cardiospermum', 'halicacabum', '(Balloon', 'vine)']
# ['Cardiospermum', 'halicacabum', '(Balloon', 'vine)']
# ['Cardiospermum', 'halicacabum', '(Balloon', 'vine)']
# ['Cardiospermum', 'halicacabum', '(Balloon', 'vine)']
# ['Cardiospermum', 'halicacabum', '(Balloon', 'vine)']
# ['Cardiospermum', 'halicacabum', '(Balloon', 'vine)']
# ['Cardiospermum', 'halicacabum', '(Balloon', 'vine)']
# ['Cardiospermum', 'halicacabum', '(Balloon', 'vine)']
# ['Cardiospermum', 'halicacabum', '(Balloon', 'vine)']
# ['Cardiospermum', 'halicacabum', '(Balloon', 'vine)']
# ['Cardiospermum', 'halicacabum', '(Balloon', 'vine)']
# ['Cardiospermum', 'halicacabum', '(Balloon', 'vine)']
# ['Cardiospermum', 'halicacabum', '(Balloon', 'vine)']
# ['Cardiospermum', 'halicacabum', '(Balloon', 'vine)']
# ['Cardiospermum', 'halicacabum', '(Balloon', 'vine)']
# ['Cardiospermum', 'halicacabum', '(Balloon', 'vine)']
# ['Cardiospermum', 'halicacabum', '(Balloon', 'vine)']
# ['Commelina', 'benghalensis', '(Benghal', 'dayflower)']
# ['Commelina', 'benghalensis', '(Benghal', 'dayflower)']
# ['Commelina', 'benghalensis', '(Benghal', 'dayflower)']
# ['Commelina', 'benghalensis', '(Benghal', 'dayflower)']
# ['Commelina', 'benghalensis', '(Benghal', 'dayflower)']
# ['Commelina', 'benghalensis', '(Benghal', 'dayflower)']
# ['Commelina', 'benghalensis', '(Benghal', 'dayflower)']
# ['Commelina', 'benghalensis', '(Benghal', 'dayflower)']
# ['Commelina', 'benghalensis', '(Benghal', 'dayflower)']
# ['Commelina', 'benghalensis', '(Benghal', 'dayflower)']
# ['Commelina', 'benghalensis', '(Benghal', 'dayflower)']
# ['Commelina', 'benghalensis', '(Benghal', 'dayflower)']
# ['Commelina', 'benghalensis', '(Benghal', 'dayflower)']
# ['Commelina', 'benghalensis', '(Benghal', 'dayflower)']
# ['Commelina', 'benghalensis', '(Benghal', 'dayflower)']
# ['Commelina', 'benghalensis', '(Benghal', 'dayflower)']
# ['Commelina', 'benghalensis', '(Benghal', 'dayflower)']
# ['Commelina', 'benghalensis', '(Benghal', 'dayflower)']
# ['Commelina', 'benghalensis', '(Benghal', 'dayflower)']
# ['Commelina', 'benghalensis', '(Benghal', 'dayflower)']
# ['Commelina', 'benghalensis', '(Benghal', 'dayflower)']
# ['Commelina', 'benghalensis', '(Benghal', 'dayflower)']
# ['Commelina', 'benghalensis', '(Benghal', 'dayflower)']
# ['Commelina', 'benghalensis', '(Benghal', 'dayflower)']
# ['Commelina', 'benghalensis', '(Benghal', 'dayflower)']
# ['Commelina', 'benghalensis', '(Benghal', 'dayflower)']
# ['Commelina', 'benghalensis', '(Benghal', 'dayflower)']
# ['Commelina', 'benghalensis', '(Benghal', 'dayflower)']
# ['Commelina', 'benghalensis', '(Benghal', 'dayflower)']
# ['Commelina', 'benghalensis', '(Benghal', 'dayflower)']
# ['Commelina', 'benghalensis', '(Benghal', 'dayflower)']
# ['Commelina', 'benghalensis', '(Benghal', 'dayflower)']
# ['Commelina', 'benghalensis', '(Benghal', 'dayflower)']
# ['Commelina', 'benghalensis', '(Benghal', 'dayflower)']
# ['Commelina', 'benghalensis', '(Benghal', 'dayflower)']
# ['Commelina', 'benghalensis', '(Benghal', 'dayflower)']
# ['Betel', '(Piper', 'betle)']
# ['Betel', '(Piper', 'betle)']
# ['Betel', '(Piper', 'betle)']
# ['Betel', '(Piper', 'betle)']
# ['Betel', '(Piper', 'betle)']
# ['Betel', '(Piper', 'betle)']
# ['Betel', '(Piper', 'betle)']
# ['Betel', '(Piper', 'betle)']
# ['Betel', '(Piper', 'betle)']
# ['Betel', '(Piper', 'betle)']
# ['Betel', '(Piper', 'betle)']
# ['Betel', '(Piper', 'betle)']
# ['Betel', '(Piper', 'betle)']
# ['Betel', '(Piper', 'betle)']
# ['Betel', '(Piper', 'betle)']
# ['Betel', '(Piper', 'betle)']
# ['Betel', '(Piper', 'betle)']
# ['Betel', '(Piper', 'betle)']
# ['Betel', '(Piper', 'betle)']
# ['Betel', '(Piper', 'betle)']
# ['Solanum', 'nigrum', '(Black', 'Night', 'Shade)']
# ['Solanum', 'nigrum', '(Black', 'Night', 'Shade)']
# ['Solanum', 'nigrum', '(Black', 'Night', 'Shade)']
# ['Solanum', 'nigrum', '(Black', 'Night', 'Shade)']
# ['Solanum', 'nigrum', '(Black', 'Night', 'Shade)']
# ['Phyllanthus', 'reticulatus', '(Black-Honey', 'Shrub)']
# ['Phyllanthus', 'reticulatus', '(Black-Honey', 'Shrub)']
# ['Phyllanthus', 'reticulatus', '(Black-Honey', 'Shrub)']
# ['Phyllanthus', 'reticulatus', '(Black-Honey', 'Shrub)']
# ['Phyllanthus', 'reticulatus', '(Black-Honey', 'Shrub)']
# ['Phyllanthus', 'reticulatus', '(Black-Honey', 'Shrub)']
# ['Phyllanthus', 'reticulatus', '(Black-Honey', 'Shrub)']
# ['Cyphostemma', 'setosum', '(Bristly', 'Wild', 'Grape)']
# ['Cyphostemma', 'setosum', '(Bristly', 'Wild', 'Grape)']
# ['Cyphostemma', 'setosum', '(Bristly', 'Wild', 'Grape)']
# ['Cyphostemma', 'setosum', '(Bristly', 'Wild', 'Grape)']
# ['Cyphostemma', 'setosum', '(Bristly', 'Wild', 'Grape)']
# ['Cyphostemma', 'setosum', '(Bristly', 'Wild', 'Grape)']
# ['Cyphostemma', 'setosum', '(Bristly', 'Wild', 'Grape)']
# ['Cyphostemma', 'setosum', '(Bristly', 'Wild', 'Grape)']
# ['Cyphostemma', 'setosum', '(Bristly', 'Wild', 'Grape)']
# ['Cyphostemma', 'setosum', '(Bristly', 'Wild', 'Grape)']
# ['Cyphostemma', 'setosum', '(Bristly', 'Wild', 'Grape)']
# ['Cyphostemma', 'setosum', '(Bristly', 'Wild', 'Grape)']
# ['Cyphostemma', 'setosum', '(Bristly', 'Wild', 'Grape)']
# ['Cyphostemma', 'setosum', '(Bristly', 'Wild', 'Grape)']
# ['Cyphostemma', 'setosum', '(Bristly', 'Wild', 'Grape)']
# ['Cyphostemma', 'setosum', '(Bristly', 'Wild', 'Grape)']
# ['Cyphostemma', 'setosum', '(Bristly', 'Wild', 'Grape)']
# ['Cyphostemma', 'setosum', '(Bristly', 'Wild', 'Grape)']
# ['Cyphostemma', 'setosum', '(Bristly', 'Wild', 'Grape)']
# ['Cyphostemma', 'setosum', '(Bristly', 'Wild', 'Grape)']
# ['Cyphostemma', 'setosum', '(Bristly', 'Wild', 'Grape)']
# ['Cyphostemma', 'setosum', '(Bristly', 'Wild', 'Grape)']
# ['Cyphostemma', 'setosum', '(Bristly', 'Wild', 'Grape)']
# ['Cyphostemma', 'setosum', '(Bristly', 'Wild', 'Grape)']
# ['Cyphostemma', 'setosum', '(Bristly', 'Wild', 'Grape)']
# ['Clitoria', 'ternatea', '(Butterfly', 'Pea)']
# ['Clitoria', 'ternatea', '(Butterfly', 'Pea)']
# ['Clitoria', 'ternatea', '(Butterfly', 'Pea)']
# ['Clitoria', 'ternatea', '(Butterfly', 'Pea)']
# ['Clitoria', 'ternatea', '(Butterfly', 'Pea)']
# ['Clitoria', 'ternatea', '(Butterfly', 'Pea)']
# ['Clitoria', 'ternatea', '(Butterfly', 'Pea)']
# ['Clitoria', 'ternatea', '(Butterfly', 'Pea)']
# ['Clitoria', 'ternatea', '(Butterfly', 'Pea)']
# ['Clitoria', 'ternatea', '(Butterfly', 'Pea)']
# ['Clitoria', 'ternatea', '(Butterfly', 'Pea)']
# ['Clitoria', 'ternatea', '(Butterfly', 'Pea)']
# ['Clitoria', 'ternatea', '(Butterfly', 'Pea)']
# ['Clitoria', 'ternatea', '(Butterfly', 'Pea)']
# ['Clitoria', 'ternatea', '(Butterfly', 'Pea)']
# ['Clitoria', 'ternatea', '(Butterfly', 'Pea)']
# ['Clitoria', 'ternatea', '(Butterfly', 'Pea)']
# ['Physalis', 'peruviana', '(Cape', 'Gooseberry)']
# ['Physalis', 'peruviana', '(Cape', 'Gooseberry)']
# ['Physalis', 'peruviana', '(Cape', 'Gooseberry)']
# ['Physalis', 'peruviana', '(Cape', 'Gooseberry)']
# ['Physalis', 'peruviana', '(Cape', 'Gooseberry)']
# ['Physalis', 'peruviana', '(Cape', 'Gooseberry)']
# ['Physalis', 'peruviana', '(Cape', 'Gooseberry)']
# ['Physalis', 'peruviana', '(Cape', 'Gooseberry)']
# ['Physalis', 'peruviana', '(Cape', 'Gooseberry)']
# ['Physalis', 'peruviana', '(Cape', 'Gooseberry)']
# ['Physalis', 'peruviana', '(Cape', 'Gooseberry)']
# ['Physalis', 'peruviana', '(Cape', 'Gooseberry)']
# ['Physalis', 'peruviana', '(Cape', 'Gooseberry)']
# ['Physalis', 'peruviana', '(Cape', 'Gooseberry)']
# ['Physalis', 'peruviana', '(Cape', 'Gooseberry)']
# ['Physalis', 'peruviana', '(Cape', 'Gooseberry)']
# ['Physalis', 'peruviana', '(Cape', 'Gooseberry)']
# ['Physalis', 'peruviana', '(Cape', 'Gooseberry)']
# ['Physalis', 'peruviana', '(Cape', 'Gooseberry)']
# ['Physalis', 'peruviana', '(Cape', 'Gooseberry)']
# ['Physalis', 'peruviana', '(Cape', 'Gooseberry)']
# ['Physalis', 'peruviana', '(Cape', 'Gooseberry)']
# ['Physalis', 'peruviana', '(Cape', 'Gooseberry)']
# ['Physalis', 'peruviana', '(Cape', 'Gooseberry)']
# ['Physalis', 'peruviana', '(Cape', 'Gooseberry)']
# ['Physalis', 'peruviana', '(Cape', 'Gooseberry)']
# ['Physalis', 'peruviana', '(Cape', 'Gooseberry)']
# ['Physalis', 'peruviana', '(Cape', 'Gooseberry)']
# ['Physalis', 'peruviana', '(Cape', 'Gooseberry)']
# ['Physalis', 'peruviana', '(Cape', 'Gooseberry)']
# ['Physalis', 'peruviana', '(Cape', 'Gooseberry)']
# ['Physalis', 'peruviana', '(Cape', 'Gooseberry)']
# ['Apium', 'graveolens', '(Celery)']
# ['Amaranthus', 'dubius', '(Chinese', 'Spinach)']
# ['Amaranthus', 'dubius', '(Chinese', 'Spinach)']
# ['Amaranthus', 'dubius', '(Chinese', 'Spinach)']
# ['Amaranthus', 'dubius', '(Chinese', 'Spinach)']
# ['Amaranthus', 'dubius', '(Chinese', 'Spinach)']
# ['Amaranthus', 'dubius', '(Chinese', 'Spinach)']
# ['Amaranthus', 'dubius', '(Chinese', 'Spinach)']
# ['Amaranthus', 'dubius', '(Chinese', 'Spinach)']
# ['Amaranthus', 'dubius', '(Chinese', 'Spinach)']
# ['Amaranthus', 'dubius', '(Chinese', 'Spinach)']
# ['Amaranthus', 'dubius', '(Chinese', 'Spinach)']
# ['Amaranthus', 'dubius', '(Chinese', 'Spinach)']
# ['Amaranthus', 'dubius', '(Chinese', 'Spinach)']
# ['Amaranthus', 'dubius', '(Chinese', 'Spinach)']
# ['Amaranthus', 'dubius', '(Chinese', 'Spinach)']
# ['Amaranthus', 'dubius', '(Chinese', 'Spinach)']
# ['Amaranthus', 'dubius', '(Chinese', 'Spinach)']
# ['Amaranthus', 'dubius', '(Chinese', 'Spinach)']
# ['Amaranthus', 'dubius', '(Chinese', 'Spinach)']
# ['Amaranthus', 'dubius', '(Chinese', 'Spinach)']
# ['Amaranthus', 'dubius', '(Chinese', 'Spinach)']
# ['Amaranthus', 'dubius', '(Chinese', 'Spinach)']
# ['Amaranthus', 'dubius', '(Chinese', 'Spinach)']
# ['Amaranthus', 'dubius', '(Chinese', 'Spinach)']
# ['Amaranthus', 'dubius', '(Chinese', 'Spinach)']
# ['Amaranthus', 'dubius', '(Chinese', 'Spinach)']
# ['Amaranthus', 'dubius', '(Chinese', 'Spinach)']
# ['Amaranthus', 'dubius', '(Chinese', 'Spinach)']
# ['Amaranthus', 'dubius', '(Chinese', 'Spinach)']
# ['Amaranthus', 'dubius', '(Chinese', 'Spinach)']
# ['Amaranthus', 'dubius', '(Chinese', 'Spinach)']
# ['Amaranthus', 'dubius', '(Chinese', 'Spinach)']
# ['Amaranthus', 'dubius', '(Chinese', 'Spinach)']
# ['Amaranthus', 'dubius', '(Chinese', 'Spinach)']
# ['Tridax', 'procumbens', '(coatbuttons)']
# ['Tridax', 'procumbens', '(coatbuttons)']
# ['Tridax', 'procumbens', '(coatbuttons)']
# ['Tridax', 'procumbens', '(coatbuttons)']
# ['Tridax', 'procumbens', '(coatbuttons)']
# ['Tridax', 'procumbens', '(coatbuttons)']
# ['Tridax', 'procumbens', '(coatbuttons)']
# ['Tridax', 'procumbens', '(coatbuttons)']
# ['Tridax', 'procumbens', '(coatbuttons)']
# ['Tridax', 'procumbens', '(coatbuttons)']
# ['Tridax', 'procumbens', '(coatbuttons)']
# ['Tridax', 'procumbens', '(coatbuttons)']
# ['Tridax', 'procumbens', '(coatbuttons)']
# ['Tridax', 'procumbens', '(coatbuttons)']
# ['Tridax', 'procumbens', '(coatbuttons)']
# ['Tridax', 'procumbens', '(coatbuttons)']
# ['Tridax', 'procumbens', '(coatbuttons)']
# ['Tridax', 'procumbens', '(coatbuttons)']
# ['Tridax', 'procumbens', '(coatbuttons)']
# ['Tridax', 'procumbens', '(coatbuttons)']
# ['Tridax', 'procumbens', '(coatbuttons)']
# ['Tridax', 'procumbens', '(coatbuttons)']
# ['Tridax', 'procumbens', '(coatbuttons)']
# ['Tridax', 'procumbens', '(coatbuttons)']
# ['Tridax', 'procumbens', '(coatbuttons)']
# ['Tridax', 'procumbens', '(coatbuttons)']
# ['Tridax', 'procumbens', '(coatbuttons)']
# ['Tridax', 'procumbens', '(coatbuttons)']
# ['Tridax', 'procumbens', '(coatbuttons)']
# ['Tridax', 'procumbens', '(coatbuttons)']
# ['Tridax', 'procumbens', '(coatbuttons)']
# ['Tridax', 'procumbens', '(coatbuttons)']
# ['Tridax', 'procumbens', '(coatbuttons)']
# ['Tridax', 'procumbens', '(coatbuttons)']
# ['Tridax', 'procumbens', '(coatbuttons)']
# ['Tridax', 'procumbens', '(coatbuttons)']
# ['Tridax', 'procumbens', '(coatbuttons)']
# ['Tridax', 'procumbens', '(coatbuttons)']
# ['Sida', 'acuta', '(Common', 'Wireweed)']
# ['Sida', 'acuta', '(Common', 'Wireweed)']
# ['Sida', 'acuta', '(Common', 'Wireweed)']
# ['Calotropis', 'gigantea', '(Crown', 'flower)']
# ['Calotropis', 'gigantea', '(Crown', 'flower)']
# ['Calotropis', 'gigantea', '(Crown', 'flower)']
# ['Calotropis', 'gigantea', '(Crown', 'flower)']
# ['Calotropis', 'gigantea', '(Crown', 'flower)']
# ['Calotropis', 'gigantea', '(Crown', 'flower)']
# ['Calotropis', 'gigantea', '(Crown', 'flower)']
# ['Calotropis', 'gigantea', '(Crown', 'flower)']
# ['Calotropis', 'gigantea', '(Crown', 'flower)']
# ['Calotropis', 'gigantea', '(Crown', 'flower)']
# ['Calotropis', 'gigantea', '(Crown', 'flower)']
# ['Calotropis', 'gigantea', '(Crown', 'flower)']
# ['Calotropis', 'gigantea', '(Crown', 'flower)']
# ['Calotropis', 'gigantea', '(Crown', 'flower)']
# ['Calotropis', 'gigantea', '(Crown', 'flower)']
# ['Calotropis', 'gigantea', '(Crown', 'flower)']
# ['Calotropis', 'gigantea', '(Crown', 'flower)']
# ['Calotropis', 'gigantea', '(Crown', 'flower)']
# ['Calotropis', 'gigantea', '(Crown', 'flower)']
# ['Calotropis', 'gigantea', '(Crown', 'flower)']
# ['Calotropis', 'gigantea', '(Crown', 'flower)']
# ['Calotropis', 'gigantea', '(Crown', 'flower)']
# ['Calotropis', 'gigantea', '(Crown', 'flower)']
# ['Calotropis', 'gigantea', '(Crown', 'flower)']
# ['Calotropis', 'gigantea', '(Crown', 'flower)']
# ['Calotropis', 'gigantea', '(Crown', 'flower)']
# ['Calotropis', 'gigantea', '(Crown', 'flower)']
# ['Calotropis', 'gigantea', '(Crown', 'flower)']
# ['Calotropis', 'gigantea', '(Crown', 'flower)']
# ['Calotropis', 'gigantea', '(Crown', 'flower)']
# ['Calotropis', 'gigantea', '(Crown', 'flower)']
# ['Calotropis', 'gigantea', '(Crown', 'flower)']
# ['Calotropis', 'gigantea', '(Crown', 'flower)']
# ['Calotropis', 'gigantea', '(Crown', 'flower)']
# ['Calotropis', 'gigantea', '(Crown', 'flower)']
# ['Calotropis', 'gigantea', '(Crown', 'flower)']
# ['Calotropis', 'gigantea', '(Crown', 'flower)']
# ['Calotropis', 'gigantea', '(Crown', 'flower)']
# ['Calotropis', 'gigantea', '(Crown', 'flower)']
# ['Calotropis', 'gigantea', '(Crown', 'flower)']
# ['Calotropis', 'gigantea', '(Crown', 'flower)']
# ['Calotropis', 'gigantea', '(Crown', 'flower)']
# ['Calotropis', 'gigantea', '(Crown', 'flower)']
# ['Calotropis', 'gigantea', '(Crown', 'flower)']
# ['Calotropis', 'gigantea', '(Crown', 'flower)']
# ['Calotropis', 'gigantea', '(Crown', 'flower)']
# ['Calotropis', 'gigantea', '(Crown', 'flower)']
# ['Calotropis', 'gigantea', '(Crown', 'flower)']
# ['Calotropis', 'gigantea', '(Crown', 'flower)']
# ['Calotropis', 'gigantea', '(Crown', 'flower)']
# ['Calotropis', 'gigantea', '(Crown', 'flower)']
# ['Calotropis', 'gigantea', '(Crown', 'flower)']
# ['Calotropis', 'gigantea', '(Crown', 'flower)']
# ['Calotropis', 'gigantea', '(Crown', 'flower)']
# ['Calotropis', 'gigantea', '(Crown', 'flower)']
# ['Calotropis', 'gigantea', '(Crown', 'flower)']
# ['Calotropis', 'gigantea', '(Crown', 'flower)']
# ['Calotropis', 'gigantea', '(Crown', 'flower)']
# ['Calotropis', 'gigantea', '(Crown', 'flower)']
# ['Calotropis', 'gigantea', '(Crown', 'flower)']
# ['Calotropis', 'gigantea', '(Crown', 'flower)']
# ['Calotropis', 'gigantea', '(Crown', 'flower)']
# ['Calotropis', 'gigantea', '(Crown', 'flower)']
# ['Sida', 'cordifolia', '(Country', 'Mallow)']
# ['Sida', 'cordifolia', '(Country', 'Mallow)']
# ['Sida', 'cordifolia', '(Country', 'Mallow)']
# ['Sida', 'cordifolia', '(Country', 'Mallow)']
# ['Sida', 'cordifolia', '(Country', 'Mallow)']
# ['Sida', 'cordifolia', '(Country', 'Mallow)']
# ['Sida', 'cordifolia', '(Country', 'Mallow)']
# ['Sida', 'cordifolia', '(Country', 'Mallow)']
# ['Sida', 'cordifolia', '(Country', 'Mallow)']
# ['Sida', 'cordifolia', '(Country', 'Mallow)']
# ['Sida', 'cordifolia', '(Country', 'Mallow)']
# ['Sida', 'cordifolia', '(Country', 'Mallow)']
# ['Sida', 'cordifolia', '(Country', 'Mallow)']
# ['Sida', 'cordifolia', '(Country', 'Mallow)']
# ['Sida', 'cordifolia', '(Country', 'Mallow)']
# ['Sida', 'cordifolia', '(Country', 'Mallow)']
# ['Sida', 'cordifolia', '(Country', 'Mallow)']
# ['Sida', 'cordifolia', '(Country', 'Mallow)']
# ['Sida', 'cordifolia', '(Country', 'Mallow)']
# ['Sida', 'cordifolia', '(Country', 'Mallow)']
# ['Sida', 'cordifolia', '(Country', 'Mallow)']
# ['Sida', 'cordifolia', '(Country', 'Mallow)']
# ['Sida', 'cordifolia', '(Country', 'Mallow)']
# ['Sida', 'cordifolia', '(Country', 'Mallow)']
# ['Sida', 'cordifolia', '(Country', 'Mallow)']
# ['Sida', 'cordifolia', '(Country', 'Mallow)']
# ['Sida', 'cordifolia', '(Country', 'Mallow)']
# ['Sida', 'cordifolia', '(Country', 'Mallow)']
# ['Sida', 'cordifolia', '(Country', 'Mallow)']
# ['Sida', 'cordifolia', '(Country', 'Mallow)']
# ['Sida', 'cordifolia', '(Country', 'Mallow)']
# ['Sida', 'cordifolia', '(Country', 'Mallow)']
# ['Sida', 'cordifolia', '(Country', 'Mallow)']
# ['Sida', 'cordifolia', '(Country', 'Mallow)']
# ['Sida', 'cordifolia', '(Country', 'Mallow)']
# ['Sida', 'cordifolia', '(Country', 'Mallow)']
# ['Sida', 'cordifolia', '(Country', 'Mallow)']
# ['Sida', 'cordifolia', '(Country', 'Mallow)']
# ['Sida', 'cordifolia', '(Country', 'Mallow)']
# ['Sida', 'cordifolia', '(Country', 'Mallow)']
# ['Sida', 'cordifolia', '(Country', 'Mallow)']
# ['Sida', 'cordifolia', '(Country', 'Mallow)']
# ['Murraya', 'koenigii', '(Curry', 'Leaf)']
# ['Murraya', 'koenigii', '(Curry', 'Leaf)']
# ['Alternanthera', 'brasiliana', '(False', 'Amarnath)']
# ['Alternanthera', 'brasiliana', '(False', 'Amarnath)']
# ['Alternanthera', 'brasiliana', '(False', 'Amarnath)']
# ['Alternanthera', 'brasiliana', '(False', 'Amarnath)']
# ['Alternanthera', 'brasiliana', '(False', 'Amarnath)']
# ['Trianthema', 'portulacastrum', '(Giant', 'Pigweed)']
# ['Trianthema', 'portulacastrum', '(Giant', 'Pigweed)']
# ['Trianthema', 'portulacastrum', '(Giant', 'Pigweed)']
# ['Trianthema', 'portulacastrum', '(Giant', 'Pigweed)']
# ['Trianthema', 'portulacastrum', '(Giant', 'Pigweed)']
# ['Trianthema', 'portulacastrum', '(Giant', 'Pigweed)']
# ['Trianthema', 'portulacastrum', '(Giant', 'Pigweed)']
# ['Trianthema', 'portulacastrum', '(Giant', 'Pigweed)']
# ['Trianthema', 'portulacastrum', '(Giant', 'Pigweed)']
# ['Trianthema', 'portulacastrum', '(Giant', 'Pigweed)']
# ['Trianthema', 'portulacastrum', '(Giant', 'Pigweed)']
# ['Trianthema', 'portulacastrum', '(Giant', 'Pigweed)']
# ['Trianthema', 'portulacastrum', '(Giant', 'Pigweed)']
# ['Trianthema', 'portulacastrum', '(Giant', 'Pigweed)']
# ['Trianthema', 'portulacastrum', '(Giant', 'Pigweed)']
# ['Trianthema', 'portulacastrum', '(Giant', 'Pigweed)']
# ['Trianthema', 'portulacastrum', '(Giant', 'Pigweed)']
# ['Trianthema', 'portulacastrum', '(Giant', 'Pigweed)']
# ['Trianthema', 'portulacastrum', '(Giant', 'Pigweed)']
# ['Trianthema', 'portulacastrum', '(Giant', 'Pigweed)']
# ['Trianthema', 'portulacastrum', '(Giant', 'Pigweed)']
# ['Trianthema', 'portulacastrum', '(Giant', 'Pigweed)']
# ['Trianthema', 'portulacastrum', '(Giant', 'Pigweed)']
# ['Trianthema', 'portulacastrum', '(Giant', 'Pigweed)']
# ['Trianthema', 'portulacastrum', '(Giant', 'Pigweed)']
# ['Trianthema', 'portulacastrum', '(Giant', 'Pigweed)']
# ['Trianthema', 'portulacastrum', '(Giant', 'Pigweed)']
# ['Trianthema', 'portulacastrum', '(Giant', 'Pigweed)']
# ['Trianthema', 'portulacastrum', '(Giant', 'Pigweed)']
# ['Trianthema', 'portulacastrum', '(Giant', 'Pigweed)']
# ['Trianthema', 'portulacastrum', '(Giant', 'Pigweed)']
# ['Trianthema', 'portulacastrum', '(Giant', 'Pigweed)']
# ['Trianthema', 'portulacastrum', '(Giant', 'Pigweed)']
# ['Trianthema', 'portulacastrum', '(Giant', 'Pigweed)']
# ['Trianthema', 'portulacastrum', '(Giant', 'Pigweed)']
# ['Trianthema', 'portulacastrum', '(Giant', 'Pigweed)']
# ['Trianthema', 'portulacastrum', '(Giant', 'Pigweed)']
# ['Trianthema', 'portulacastrum', '(Giant', 'Pigweed)']
# ['Trianthema', 'portulacastrum', '(Giant', 'Pigweed)']
# ['Trianthema', 'portulacastrum', '(Giant', 'Pigweed)']
# ['Trianthema', 'portulacastrum', '(Giant', 'Pigweed)']
# ['Trianthema', 'portulacastrum', '(Giant', 'Pigweed)']
# ['Trianthema', 'portulacastrum', '(Giant', 'Pigweed)']
# ['Trianthema', 'portulacastrum', '(Giant', 'Pigweed)']
# ['Trianthema', 'portulacastrum', '(Giant', 'Pigweed)']
# ['Trianthema', 'portulacastrum', '(Giant', 'Pigweed)']
# ['Trianthema', 'portulacastrum', '(Giant', 'Pigweed)']
# ['Trianthema', 'portulacastrum', '(Giant', 'Pigweed)']
# ['Trianthema', 'portulacastrum', '(Giant', 'Pigweed)']
# ['Trianthema', 'portulacastrum', '(Giant', 'Pigweed)']
# ['Trianthema', 'portulacastrum', '(Giant', 'Pigweed)']
# ['Hibiscus', 'sabdariffa', '(Gongura)']
# ['Andrographis', 'paniculata', '(Green', 'Chireta)']
# ['Andrographis', 'paniculata', '(Green', 'Chireta)']
# ['Andrographis', 'paniculata', '(Green', 'Chireta)']
# ['Andrographis', 'paniculata', '(Green', 'Chireta)']
# ['Andrographis', 'paniculata', '(Green', 'Chireta)']
# ['Andrographis', 'paniculata', '(Green', 'Chireta)']
# ['Andrographis', 'paniculata', '(Green', 'Chireta)']
# ['Andrographis', 'paniculata', '(Green', 'Chireta)']
# ['Andrographis', 'paniculata', '(Green', 'Chireta)']
# ['Andrographis', 'paniculata', '(Green', 'Chireta)']
# ['Andrographis', 'paniculata', '(Green', 'Chireta)']
# ['Andrographis', 'paniculata', '(Green', 'Chireta)']
# ['Andrographis', 'paniculata', '(Green', 'Chireta)']
# ['Andrographis', 'paniculata', '(Green', 'Chireta)']
# ['Andrographis', 'paniculata', '(Green', 'Chireta)']
# ['Andrographis', 'paniculata', '(Green', 'Chireta)']
# ['Andrographis', 'paniculata', '(Green', 'Chireta)']
# ['Andrographis', 'paniculata', '(Green', 'Chireta)']
# ['Andrographis', 'paniculata', '(Green', 'Chireta)']
# ['Andrographis', 'paniculata', '(Green', 'Chireta)']
# ['Andrographis', 'paniculata', '(Green', 'Chireta)']
# ['Andrographis', 'paniculata', '(Green', 'Chireta)']
# ['Andrographis', 'paniculata', '(Green', 'Chireta)']
# ['Andrographis', 'paniculata', '(Green', 'Chireta)']
# ['Andrographis', 'paniculata', '(Green', 'Chireta)']
# ['Andrographis', 'paniculata', '(Green', 'Chireta)']
# ['Andrographis', 'paniculata', '(Green', 'Chireta)']
# ['Tinospora', 'cordifolia', '(Heart-leaved', 'moonseed)']
# ['Tinospora', 'cordifolia', '(Heart-leaved', 'moonseed)']
# ['Tinospora', 'cordifolia', '(Heart-leaved', 'moonseed)']
# ['Tinospora', 'cordifolia', '(Heart-leaved', 'moonseed)']
# ['Tinospora', 'cordifolia', '(Heart-leaved', 'moonseed)']
# ['Tinospora', 'cordifolia', '(Heart-leaved', 'moonseed)']
# ['Tinospora', 'cordifolia', '(Heart-leaved', 'moonseed)']
# ['Tinospora', 'cordifolia', '(Heart-leaved', 'moonseed)']
# ['Tinospora', 'cordifolia', '(Heart-leaved', 'moonseed)']
# ['Tinospora', 'cordifolia', '(Heart-leaved', 'moonseed)']
# ['Tinospora', 'cordifolia', '(Heart-leaved', 'moonseed)']
# ['Tinospora', 'cordifolia', '(Heart-leaved', 'moonseed)']
# ['Tinospora', 'cordifolia', '(Heart-leaved', 'moonseed)']
# ['Tinospora', 'cordifolia', '(Heart-leaved', 'moonseed)']
# ['Tinospora', 'cordifolia', '(Heart-leaved', 'moonseed)']
# ['Tinospora', 'cordifolia', '(Heart-leaved', 'moonseed)']
# ['Tinospora', 'cordifolia', '(Heart-leaved', 'moonseed)']
# ['Tinospora', 'cordifolia', '(Heart-leaved', 'moonseed)']
# ['Tinospora', 'cordifolia', '(Heart-leaved', 'moonseed)']
# ['Tinospora', 'cordifolia', '(Heart-leaved', 'moonseed)']
# ['Tinospora', 'cordifolia', '(Heart-leaved', 'moonseed)']
# ['Tinospora', 'cordifolia', '(Heart-leaved', 'moonseed)']
# ['Tinospora', 'cordifolia', '(Heart-leaved', 'moonseed)']
# ['Tinospora', 'cordifolia', '(Heart-leaved', 'moonseed)']
# ['Tinospora', 'cordifolia', '(Heart-leaved', 'moonseed)']
# ['Tinospora', 'cordifolia', '(Heart-leaved', 'moonseed)']
# ['Tinospora', 'cordifolia', '(Heart-leaved', 'moonseed)']
# ['Tinospora', 'cordifolia', '(Heart-leaved', 'moonseed)']
# ['Tinospora', 'cordifolia', '(Heart-leaved', 'moonseed)']
# ['Tinospora', 'cordifolia', '(Heart-leaved', 'moonseed)']
# ['Tinospora', 'cordifolia', '(Heart-leaved', 'moonseed)']
# ['Tinospora', 'cordifolia', '(Heart-leaved', 'moonseed)']
# ['Tinospora', 'cordifolia', '(Heart-leaved', 'moonseed)']
# ['Tinospora', 'cordifolia', '(Heart-leaved', 'moonseed)']
# ['Tinospora', 'cordifolia', '(Heart-leaved', 'moonseed)']
# ['Tinospora', 'cordifolia', '(Heart-leaved', 'moonseed)']
# ['Tinospora', 'cordifolia', '(Heart-leaved', 'moonseed)']
# ['Tinospora', 'cordifolia', '(Heart-leaved', 'moonseed)']
# ['Tinospora', 'cordifolia', '(Heart-leaved', 'moonseed)']
# ['Tinospora', 'cordifolia', '(Heart-leaved', 'moonseed)']
# ['Tinospora', 'cordifolia', '(Heart-leaved', 'moonseed)']
# ['Tinospora', 'cordifolia', '(Heart-leaved', 'moonseed)']
# ['Tinospora', 'cordifolia', '(Heart-leaved', 'moonseed)']
# ['Tinospora', 'cordifolia', '(Heart-leaved', 'moonseed)']
# ['Tinospora', 'cordifolia', '(Heart-leaved', 'moonseed)']
# ['Tinospora', 'cordifolia', '(Heart-leaved', 'moonseed)']
# ['Tinospora', 'cordifolia', '(Heart-leaved', 'moonseed)']
# ['Tinospora', 'cordifolia', '(Heart-leaved', 'moonseed)']
# ['Tinospora', 'cordifolia', '(Heart-leaved', 'moonseed)']
# ['Tinospora', 'cordifolia', '(Heart-leaved', 'moonseed)']
# ['Tinospora', 'cordifolia', '(Heart-leaved', 'moonseed)']
# ['Tinospora', 'cordifolia', '(Heart-leaved', 'moonseed)']
# ['Tinospora', 'cordifolia', '(Heart-leaved', 'moonseed)']
# ['Tinospora', 'cordifolia', '(Heart-leaved', 'moonseed)']
# ['Tinospora', 'cordifolia', '(Heart-leaved', 'moonseed)']
# ['Tinospora', 'cordifolia', '(Heart-leaved', 'moonseed)']
# ['Tinospora', 'cordifolia', '(Heart-leaved', 'moonseed)']
# ['Tinospora', 'cordifolia', '(Heart-leaved', 'moonseed)']
# ['Tinospora', 'cordifolia', '(Heart-leaved', 'moonseed)']
# ['Tinospora', 'cordifolia', '(Heart-leaved', 'moonseed)']
# ['Tinospora', 'cordifolia', '(Heart-leaved', 'moonseed)']
# ['Tinospora', 'cordifolia', '(Heart-leaved', 'moonseed)']
# ['Tinospora', 'cordifolia', '(Heart-leaved', 'moonseed)']
# ['Tinospora', 'cordifolia', '(Heart-leaved', 'moonseed)']
# ['Tinospora', 'cordifolia', '(Heart-leaved', 'moonseed)']
# ['Tinospora', 'cordifolia', '(Heart-leaved', 'moonseed)']
# ['Tinospora', 'cordifolia', '(Heart-leaved', 'moonseed)']
# ['Ocimum', 'tenuiflorum', '(Holy', 'Basil)']
# ['Ocimum', 'tenuiflorum', '(Holy', 'Basil)']
# ['Ocimum', 'tenuiflorum', '(Holy', 'Basil)']
# ['Ocimum', 'tenuiflorum', '(Holy', 'Basil)']
# ['Ocimum', 'tenuiflorum', '(Holy', 'Basil)']
# ['Ocimum', 'tenuiflorum', '(Holy', 'Basil)']
# ['Ocimum', 'tenuiflorum', '(Holy', 'Basil)']
# ['Ocimum', 'tenuiflorum', '(Holy', 'Basil)']
# ['Ocimum', 'tenuiflorum', '(Holy', 'Basil)']
# ['Ocimum', 'tenuiflorum', '(Holy', 'Basil)']
# ['Ocimum', 'tenuiflorum', '(Holy', 'Basil)']
# ['Ocimum', 'tenuiflorum', '(Holy', 'Basil)']
# ['Ocimum', 'tenuiflorum', '(Holy', 'Basil)']
# ['Ocimum', 'tenuiflorum', '(Holy', 'Basil)']
# ['Ocimum', 'tenuiflorum', '(Holy', 'Basil)']
# ['Ocimum', 'tenuiflorum', '(Holy', 'Basil)']
# ['Ocimum', 'tenuiflorum', '(Holy', 'Basil)']
# ['Ocimum', 'tenuiflorum', '(Holy', 'Basil)']
# ['Acalypha', 'indica', '(Indian', 'CopperLeaf)']
# ['Acalypha', 'indica', '(Indian', 'CopperLeaf)']
# ['Acalypha', 'indica', '(Indian', 'CopperLeaf)']
# ['Acalypha', 'indica', '(Indian', 'CopperLeaf)']
# ['Acalypha', 'indica', '(Indian', 'CopperLeaf)']
# ['Acalypha', 'indica', '(Indian', 'CopperLeaf)']
# ['Acalypha', 'indica', '(Indian', 'CopperLeaf)']
# ['Acalypha', 'indica', '(Indian', 'CopperLeaf)']
# ['Acalypha', 'indica', '(Indian', 'CopperLeaf)']
# ['Acalypha', 'indica', '(Indian', 'CopperLeaf)']
# ['Acalypha', 'indica', '(Indian', 'CopperLeaf)']
# ['Acalypha', 'indica', '(Indian', 'CopperLeaf)']
# ['Acalypha', 'indica', '(Indian', 'CopperLeaf)']
# ['Acalypha', 'indica', '(Indian', 'CopperLeaf)']
# ['Acalypha', 'indica', '(Indian', 'CopperLeaf)']
# ['Acalypha', 'indica', '(Indian', 'CopperLeaf)']
# ['Acalypha', 'indica', '(Indian', 'CopperLeaf)']
# ['Acalypha', 'indica', '(Indian', 'CopperLeaf)']
# ['Acalypha', 'indica', '(Indian', 'CopperLeaf)']
# ['Acalypha', 'indica', '(Indian', 'CopperLeaf)']
# ['Acalypha', 'indica', '(Indian', 'CopperLeaf)']
# ['Acalypha', 'indica', '(Indian', 'CopperLeaf)']
# ['Acalypha', 'indica', '(Indian', 'CopperLeaf)']
# ['Acalypha', 'indica', '(Indian', 'CopperLeaf)']
# ['Acalypha', 'indica', '(Indian', 'CopperLeaf)']
# ['Acalypha', 'indica', '(Indian', 'CopperLeaf)']
# ['Acalypha', 'indica', '(Indian', 'CopperLeaf)']
# ['Acalypha', 'indica', '(Indian', 'CopperLeaf)']
# ['Acalypha', 'indica', '(Indian', 'CopperLeaf)']
# ['Acalypha', 'indica', '(Indian', 'CopperLeaf)']
# ['Acalypha', 'indica', '(Indian', 'CopperLeaf)']
# ['Acalypha', 'indica', '(Indian', 'CopperLeaf)']
# ['Acalypha', 'indica', '(Indian', 'CopperLeaf)']
# ['Acalypha', 'indica', '(Indian', 'CopperLeaf)']
# ['Acalypha', 'indica', '(Indian', 'CopperLeaf)']
# ['Acalypha', 'indica', '(Indian', 'CopperLeaf)']
# ['Acalypha', 'indica', '(Indian', 'CopperLeaf)']
# ['Acalypha', 'indica', '(Indian', 'CopperLeaf)']
# ['Acalypha', 'indica', '(Indian', 'CopperLeaf)']
# ['Acalypha', 'indica', '(Indian', 'CopperLeaf)']
# ['Acalypha', 'indica', '(Indian', 'CopperLeaf)']
# ['Acalypha', 'indica', '(Indian', 'CopperLeaf)']
# ['Acalypha', 'indica', '(Indian', 'CopperLeaf)']
# ['Ziziphus', 'mauritiana', '(Indian', 'Jujube)']
# ['Ziziphus', 'mauritiana', '(Indian', 'Jujube)']
# ['Ziziphus', 'mauritiana', '(Indian', 'Jujube)']
# ['Ziziphus', 'mauritiana', '(Indian', 'Jujube)']
# ['Ziziphus', 'mauritiana', '(Indian', 'Jujube)']
# ['Ziziphus', 'mauritiana', '(Indian', 'Jujube)']
# ['Ziziphus', 'mauritiana', '(Indian', 'Jujube)']
# ['Ziziphus', 'mauritiana', '(Indian', 'Jujube)']
# ['Ziziphus', 'mauritiana', '(Indian', 'Jujube)']
# ['Ziziphus', 'mauritiana', '(Indian', 'Jujube)']
# ['Ziziphus', 'mauritiana', '(Indian', 'Jujube)']
# ['Ziziphus', 'mauritiana', '(Indian', 'Jujube)']
# ['Ziziphus', 'mauritiana', '(Indian', 'Jujube)']
# ['Ziziphus', 'mauritiana', '(Indian', 'Jujube)']
# ['Ziziphus', 'mauritiana', '(Indian', 'Jujube)']
# ['Ziziphus', 'mauritiana', '(Indian', 'Jujube)']
# ['Ziziphus', 'mauritiana', '(Indian', 'Jujube)']
# ['Ziziphus', 'mauritiana', '(Indian', 'Jujube)']
# ['Ziziphus', 'mauritiana', '(Indian', 'Jujube)']
# ['Ziziphus', 'mauritiana', '(Indian', 'Jujube)']
# ['Ziziphus', 'mauritiana', '(Indian', 'Jujube)']
# ['Ziziphus', 'mauritiana', '(Indian', 'Jujube)']
# ['Ziziphus', 'mauritiana', '(Indian', 'Jujube)']
# ['Ziziphus', 'mauritiana', '(Indian', 'Jujube)']
# ['Centella', 'asiatica', '(Indian', 'pennywort)']
# ['Centella', 'asiatica', '(Indian', 'pennywort)']
# ['Centella', 'asiatica', '(Indian', 'pennywort)']
# ['Centella', 'asiatica', '(Indian', 'pennywort)']
# ['Centella', 'asiatica', '(Indian', 'pennywort)']
# ['Centella', 'asiatica', '(Indian', 'pennywort)']
# ['Centella', 'asiatica', '(Indian', 'pennywort)']
# ['Centella', 'asiatica', '(Indian', 'pennywort)']
# ['Centella', 'asiatica', '(Indian', 'pennywort)']
# ['Centella', 'asiatica', '(Indian', 'pennywort)']
# ['Centella', 'asiatica', '(Indian', 'pennywort)']
# ['Centella', 'asiatica', '(Indian', 'pennywort)']
# ['Centella', 'asiatica', '(Indian', 'pennywort)']
# ['Centella', 'asiatica', '(Indian', 'pennywort)']
# ['Centella', 'asiatica', '(Indian', 'pennywort)']
# ['Centella', 'asiatica', '(Indian', 'pennywort)']
# ['Centella', 'asiatica', '(Indian', 'pennywort)']
# ['Centella', 'asiatica', '(Indian', 'pennywort)']
# ['Centella', 'asiatica', '(Indian', 'pennywort)']
# ['Centella', 'asiatica', '(Indian', 'pennywort)']
# ['Centella', 'asiatica', '(Indian', 'pennywort)']
# ['Centella', 'asiatica', '(Indian', 'pennywort)']
# ['Hemidesmus', 'indicus', '(Indian', 'Sarsaparilla)']
# ['Hemidesmus', 'indicus', '(Indian', 'Sarsaparilla)']
# ['Hemidesmus', 'indicus', '(Indian', 'Sarsaparilla)']
# ['Hemidesmus', 'indicus', '(Indian', 'Sarsaparilla)']
# ['Hemidesmus', 'indicus', '(Indian', 'Sarsaparilla)']
# ['Hemidesmus', 'indicus', '(Indian', 'Sarsaparilla)']
# ['Hemidesmus', 'indicus', '(Indian', 'Sarsaparilla)']
# ['Hemidesmus', 'indicus', '(Indian', 'Sarsaparilla)']
# ['Tragia', 'involucrata', '(Indian', 'Stinging', 'Nettle)']
# ['Tragia', 'involucrata', '(Indian', 'Stinging', 'Nettle)']
# ['Tragia', 'involucrata', '(Indian', 'Stinging', 'Nettle)']
# ['Tragia', 'involucrata', '(Indian', 'Stinging', 'Nettle)']
# ['Tragia', 'involucrata', '(Indian', 'Stinging', 'Nettle)']
# ['Tragia', 'involucrata', '(Indian', 'Stinging', 'Nettle)']
# ['Tragia', 'involucrata', '(Indian', 'Stinging', 'Nettle)']
# ['Tragia', 'involucrata', '(Indian', 'Stinging', 'Nettle)']
# ['Tragia', 'involucrata', '(Indian', 'Stinging', 'Nettle)']
# ['Tragia', 'involucrata', '(Indian', 'Stinging', 'Nettle)']
# ['Tragia', 'involucrata', '(Indian', 'Stinging', 'Nettle)']
# ['Tragia', 'involucrata', '(Indian', 'Stinging', 'Nettle)']
# ['Tragia', 'involucrata', '(Indian', 'Stinging', 'Nettle)']
# ['Tragia', 'involucrata', '(Indian', 'Stinging', 'Nettle)']
# ['Tragia', 'involucrata', '(Indian', 'Stinging', 'Nettle)']
# ['Tragia', 'involucrata', '(Indian', 'Stinging', 'Nettle)']
# ['Tragia', 'involucrata', '(Indian', 'Stinging', 'Nettle)']
# ['Tragia', 'involucrata', '(Indian', 'Stinging', 'Nettle)']
# ['Tragia', 'involucrata', '(Indian', 'Stinging', 'Nettle)']
# ['Tragia', 'involucrata', '(Indian', 'Stinging', 'Nettle)']
# ['Tragia', 'involucrata', '(Indian', 'Stinging', 'Nettle)']
# ['Tragia', 'involucrata', '(Indian', 'Stinging', 'Nettle)']
# ['Tragia', 'involucrata', '(Indian', 'Stinging', 'Nettle)']
# ['Tragia', 'involucrata', '(Indian', 'Stinging', 'Nettle)']
# ['Tragia', 'involucrata', '(Indian', 'Stinging', 'Nettle)']
# ['Tragia', 'involucrata', '(Indian', 'Stinging', 'Nettle)']
# ['Tragia', 'involucrata', '(Indian', 'Stinging', 'Nettle)']
# ['Tragia', 'involucrata', '(Indian', 'Stinging', 'Nettle)']
# ['Tragia', 'involucrata', '(Indian', 'Stinging', 'Nettle)']
# ['Tragia', 'involucrata', '(Indian', 'Stinging', 'Nettle)']
# ['Tragia', 'involucrata', '(Indian', 'Stinging', 'Nettle)']
# ['Tragia', 'involucrata', '(Indian', 'Stinging', 'Nettle)']
# ['Tragia', 'involucrata', '(Indian', 'Stinging', 'Nettle)']
# ['Tragia', 'involucrata', '(Indian', 'Stinging', 'Nettle)']
# ['Tragia', 'involucrata', '(Indian', 'Stinging', 'Nettle)']
# ['Tragia', 'involucrata', '(Indian', 'Stinging', 'Nettle)']
# ['Tragia', 'involucrata', '(Indian', 'Stinging', 'Nettle)']
# ['Tragia', 'involucrata', '(Indian', 'Stinging', 'Nettle)']
# ['Tragia', 'involucrata', '(Indian', 'Stinging', 'Nettle)']
# ['Tragia', 'involucrata', '(Indian', 'Stinging', 'Nettle)']
# ['Tragia', 'involucrata', '(Indian', 'Stinging', 'Nettle)']
# ['Tragia', 'involucrata', '(Indian', 'Stinging', 'Nettle)']
# ['Tragia', 'involucrata', '(Indian', 'Stinging', 'Nettle)']
# ['Tragia', 'involucrata', '(Indian', 'Stinging', 'Nettle)']
# ['Tragia', 'involucrata', '(Indian', 'Stinging', 'Nettle)']
# ['Tragia', 'involucrata', '(Indian', 'Stinging', 'Nettle)']
# ['Datura', 'metel', '(Indian', 'Thornapple)']
# ['Datura', 'metel', '(Indian', 'Thornapple)']
# ['Datura', 'metel', '(Indian', 'Thornapple)']
# ['Datura', 'metel', '(Indian', 'Thornapple)']
# ['Datura', 'metel', '(Indian', 'Thornapple)']
# ['Datura', 'metel', '(Indian', 'Thornapple)']
# ['Datura', 'metel', '(Indian', 'Thornapple)']
# ['Datura', 'metel', '(Indian', 'Thornapple)']
# ['Datura', 'metel', '(Indian', 'Thornapple)']
# ['Datura', 'metel', '(Indian', 'Thornapple)']
# ['Datura', 'metel', '(Indian', 'Thornapple)']
# ['Datura', 'metel', '(Indian', 'Thornapple)']
# ['Datura', 'metel', '(Indian', 'Thornapple)']
# ['Artemisia', 'pallens', '(Indian', 'wormwood)']
# ['Artemisia', 'pallens', '(Indian', 'wormwood)']
# ['Artemisia', 'pallens', '(Indian', 'wormwood)']
# ['Artemisia', 'pallens', '(Indian', 'wormwood)']
# ['Artemisia', 'pallens', '(Indian', 'wormwood)']
# ['Artemisia', 'pallens', '(Indian', 'wormwood)']
# ['Artemisia', 'pallens', '(Indian', 'wormwood)']
# ['Artemisia', 'pallens', '(Indian', 'wormwood)']
# ['Artemisia', 'pallens', '(Indian', 'wormwood)']
# ['Artemisia', 'pallens', '(Indian', 'wormwood)']
# ['Artemisia', 'pallens', '(Indian', 'wormwood)']
# ['Artemisia', 'pallens', '(Indian', 'wormwood)']
# ['Artemisia', 'pallens', '(Indian', 'wormwood)']
# ['Artemisia', 'pallens', '(Indian', 'wormwood)']
# ['Artemisia', 'pallens', '(Indian', 'wormwood)']
# ['Artemisia', 'pallens', '(Indian', 'wormwood)']
# ['Coccinia', 'grandis', '(Ivy', 'Gourd)']
# ['Coccinia', 'grandis', '(Ivy', 'Gourd)']
# ['Coccinia', 'grandis', '(Ivy', 'Gourd)']
# ['Coccinia', 'grandis', '(Ivy', 'Gourd)']
# ['Coccinia', 'grandis', '(Ivy', 'Gourd)']
# ['Coccinia', 'grandis', '(Ivy', 'Gourd)']
# ['Coccinia', 'grandis', '(Ivy', 'Gourd)']
# ['Coccinia', 'grandis', '(Ivy', 'Gourd)']
# ['Coccinia', 'grandis', '(Ivy', 'Gourd)']
# ['Coccinia', 'grandis', '(Ivy', 'Gourd)']
# ['Coccinia', 'grandis', '(Ivy', 'Gourd)']
# ['Coccinia', 'grandis', '(Ivy', 'Gourd)']
# ['Coccinia', 'grandis', '(Ivy', 'Gourd)']
# ['Coccinia', 'grandis', '(Ivy', 'Gourd)']
# ['Coccinia', 'grandis', '(Ivy', 'Gourd)']
# ['Coccinia', 'grandis', '(Ivy', 'Gourd)']
# ['Coccinia', 'grandis', '(Ivy', 'Gourd)']
# ['Coccinia', 'grandis', '(Ivy', 'Gourd)']
# ['Coccinia', 'grandis', '(Ivy', 'Gourd)']
# ['Coccinia', 'grandis', '(Ivy', 'Gourd)']
# ['Hygrophila', 'auriculata', '(Kokilaksha)']
# ['Hygrophila', 'auriculata', '(Kokilaksha)']
# ['Hygrophila', 'auriculata', '(Kokilaksha)']
# ['Hygrophila', 'auriculata', '(Kokilaksha)']
# ['Hygrophila', 'auriculata', '(Kokilaksha)']
# ['Hygrophila', 'auriculata', '(Kokilaksha)']
# ['Hygrophila', 'auriculata', '(Kokilaksha)']
# ['Hygrophila', 'auriculata', '(Kokilaksha)']
# ['Hygrophila', 'auriculata', '(Kokilaksha)']
# ['Hygrophila', 'auriculata', '(Kokilaksha)']
# ['Hygrophila', 'auriculata', '(Kokilaksha)']
# ['Hygrophila', 'auriculata', '(Kokilaksha)']
# ['Hygrophila', 'auriculata', '(Kokilaksha)']
# ['Hygrophila', 'auriculata', '(Kokilaksha)']
# ['Hygrophila', 'auriculata', '(Kokilaksha)']
# ['Hygrophila', 'auriculata', '(Kokilaksha)']
# ['Hygrophila', 'auriculata', '(Kokilaksha)']
# ['Hygrophila', 'auriculata', '(Kokilaksha)']
# ['Hygrophila', 'auriculata', '(Kokilaksha)']
# ['Hygrophila', 'auriculata', '(Kokilaksha)']
# ['Hygrophila', 'auriculata', '(Kokilaksha)']
# ['Hygrophila', 'auriculata', '(Kokilaksha)']
# ['Hygrophila', 'auriculata', '(Kokilaksha)']
# ['Hygrophila', 'auriculata', '(Kokilaksha)']
# ['Hygrophila', 'auriculata', '(Kokilaksha)']
# ['Hygrophila', 'auriculata', '(Kokilaksha)']
# ['Hygrophila', 'auriculata', '(Kokilaksha)']
# ['Hygrophila', 'auriculata', '(Kokilaksha)']
# ['Hygrophila', 'auriculata', '(Kokilaksha)']
# ['Celosia', '(Lagos', 'Spinach)']
# ['Celosia', '(Lagos', 'Spinach)']
# ['Chenopodium', 'album', '(Lambs', 'Quarters)']
# ['Chenopodium', 'album', '(Lambs', 'Quarters)']
# ['Chenopodium', 'album', '(Lambs', 'Quarters)']
# ['Chenopodium', 'album', '(Lambs', 'Quarters)']
# ['Chenopodium', 'album', '(Lambs', 'Quarters)']
# ['Chenopodium', 'album', '(Lambs', 'Quarters)']
# ['Chenopodium', 'album', '(Lambs', 'Quarters)']
# ['Chenopodium', 'album', '(Lambs', 'Quarters)']
# ['Chenopodium', 'album', '(Lambs', 'Quarters)']
# ['Chenopodium', 'album', '(Lambs', 'Quarters)']
# ['Chenopodium', 'album', '(Lambs', 'Quarters)']
# ['Clematis', 'tangutica', '(Trellis', 'Vine)']
# ['Clematis', 'tangutica', '(Trellis', 'Vine)']
# ['Clematis', 'tangutica', '(Trellis', 'Vine)']
# ['Clematis', 'tangutica', '(Trellis', 'Vine)']
# ['Clematis', 'tangutica', '(Trellis', 'Vine)']
# ['Clematis', 'tangutica', '(Trellis', 'Vine)']
# ['Clematis', 'tangutica', '(Trellis', 'Vine)']
# ['Clematis', 'tangutica', '(Trellis', 'Vine)']
# ['Clematis', 'tangutica', '(Trellis', 'Vine)']
# ['Clematis', 'tangutica', '(Trellis', 'Vine)']
# ['Clematis', 'tangutica', '(Trellis', 'Vine)']
# ['Clematis', 'tangutica', '(Trellis', 'Vine)']
# ['Clematis', 'tangutica', '(Trellis', 'Vine)']
# ['Clematis', 'tangutica', '(Trellis', 'Vine)']
# ['Clematis', 'tangutica', '(Trellis', 'Vine)']
# ['Clematis', 'tangutica', '(Trellis', 'Vine)']
# ['Clematis', 'tangutica', '(Trellis', 'Vine)']
# ['Clematis', 'tangutica', '(Trellis', 'Vine)']
# ['Clematis', 'tangutica', '(Trellis', 'Vine)']
# ['Clematis', 'tangutica', '(Trellis', 'Vine)']
# ['Clematis', 'tangutica', '(Trellis', 'Vine)']
# ...
# ['Achyranthes', 'aspera', '(Prickly', 'Chaff', 'Flower)']
# ['Achyranthes', 'aspera', '(Prickly', 'Chaff', 'Flower)']
# ['Achyranthes', 'aspera', '(Prickly', 'Chaff', 'Flower)']
# ['Achyranthes', 'aspera', '(Prickly', 'Chaff', 'Flower)']
# ['Achyranthes', 'aspera', '(Prickly', 'Chaff', 'Flower)']
# ['Achyranthes', 'aspera', '(Prickly', 'Chaff', 'Flower)']
# ['Achyranthes', 'aspera', '(Prickly', 'Chaff', 'Flower)']
# ['Achyranthes', 'aspera', '(Prickly', 'Chaff', 'Flower)']
# ['Achyranthes', 'aspera', '(Prickly', 'Chaff', 'Flower)']
# ['Achyranthes', 'aspera', '(Prickly', 'Chaff', 'Flower)']
# ['Achyranthes', 'aspera', '(Prickly', 'Chaff', 'Flower)']
# ['Dicliptera', 'paniculata', '', '(Panicled', 'Foldwing)']
# ['Dicliptera', 'paniculata', '', '(Panicled', 'Foldwing)']
# ['Dicliptera', 'paniculata', '', '(Panicled', 'Foldwing)']
# ['Dicliptera', 'paniculata', '', '(Panicled', 'Foldwing)']
# ['Dicliptera', 'paniculata', '', '(Panicled', 'Foldwing)']
# ['Dicliptera', 'paniculata', '', '(Panicled', 'Foldwing)']
# ['Dicliptera', 'paniculata', '', '(Panicled', 'Foldwing)']
# ['Dicliptera', 'paniculata', '', '(Panicled', 'Foldwing)']
# ['Dicliptera', 'paniculata', '', '(Panicled', 'Foldwing)']
# ['Dicliptera', 'paniculata', '', '(Panicled', 'Foldwing)']
# ['Dicliptera', 'paniculata', '', '(Panicled', 'Foldwing)']
# ['Dicliptera', 'paniculata', '', '(Panicled', 'Foldwing)']
# ['Dicliptera', 'paniculata', '', '(Panicled', 'Foldwing)']
# ['Dicliptera', 'paniculata', '', '(Panicled', 'Foldwing)']
# ['Dicliptera', 'paniculata', '', '(Panicled', 'Foldwing)']
# ['Dicliptera', 'paniculata', '', '(Panicled', 'Foldwing)']
# ['Dicliptera', 'paniculata', '', '(Panicled', 'Foldwing)']
# ['Dicliptera', 'paniculata', '', '(Panicled', 'Foldwing)']
# ['Dicliptera', 'paniculata', '', '(Panicled', 'Foldwing)']
# ['Dicliptera', 'paniculata', '', '(Panicled', 'Foldwing)']
# ['Dicliptera', 'paniculata', '', '(Panicled', 'Foldwing)']
# ['Dicliptera', 'paniculata', '', '(Panicled', 'Foldwing)']
# ['Dicliptera', 'paniculata', '', '(Panicled', 'Foldwing)']
# ['Dicliptera', 'paniculata', '', '(Panicled', 'Foldwing)']
# ['Dicliptera', 'paniculata', '', '(Panicled', 'Foldwing)']
# ['Dicliptera', 'paniculata', '', '(Panicled', 'Foldwing)']
# ['Dicliptera', 'paniculata', '', '(Panicled', 'Foldwing)']
# ['Dicliptera', 'paniculata', '', '(Panicled', 'Foldwing)']
# ['Dicliptera', 'paniculata', '', '(Panicled', 'Foldwing)']
# ['Dicliptera', 'paniculata', '', '(Panicled', 'Foldwing)']
# ['Dicliptera', 'paniculata', '', '(Panicled', 'Foldwing)']
# ['Dicliptera', 'paniculata', '', '(Panicled', 'Foldwing)']
# ['Dicliptera', 'paniculata', '', '(Panicled', 'Foldwing)']
# ['Dicliptera', 'paniculata', '', '(Panicled', 'Foldwing)']
# ['Dicliptera', 'paniculata', '', '(Panicled', 'Foldwing)']
# ['Dicliptera', 'paniculata', '', '(Panicled', 'Foldwing)']
# ['Dicliptera', 'paniculata', '', '(Panicled', 'Foldwing)']
# ['Dicliptera', 'paniculata', '', '(Panicled', 'Foldwing)']
# ['Dicliptera', 'paniculata', '', '(Panicled', 'Foldwing)']
# ['Dicliptera', 'paniculata', '', '(Panicled', 'Foldwing)']
# ['Dicliptera', 'paniculata', '', '(Panicled', 'Foldwing)']
# ['Dicliptera', 'paniculata', '', '(Panicled', 'Foldwing)']
# ['Spinacia', 'oleracea', '(Palak)']
# ['Spinacia', 'oleracea', '(Palak)']
# ['Spinacia', 'oleracea', '(Palak)']
# ['Spinacia', 'oleracea', '(Palak)']
# ['Spinacia', 'oleracea', '(Palak)']
# ['Spinacia', 'oleracea', '(Palak)']
# ['Spinacia', 'oleracea', '(Palak)']
# ['Spinacia', 'oleracea', '(Palak)']
# ['Brassica', 'juncea', '(Mustard)']
# ['Brassica', 'juncea', '(Mustard)']
# ['Brassica', 'juncea', '(Mustard)']
# ['Brassica', 'juncea', '(Mustard)']
# ['Aerva', 'lanata', '(Mountain', 'Knotgrass)']
# ['Aerva', 'lanata', '(Mountain', 'Knotgrass)']
# ['Aerva', 'lanata', '(Mountain', 'Knotgrass)']
# ['Aerva', 'lanata', '(Mountain', 'Knotgrass)']
# ['Aerva', 'lanata', '(Mountain', 'Knotgrass)']
# ['Aerva', 'lanata', '(Mountain', 'Knotgrass)']
# ['Aerva', 'lanata', '(Mountain', 'Knotgrass)']
# ['Aerva', 'lanata', '(Mountain', 'Knotgrass)']
# ['Aerva', 'lanata', '(Mountain', 'Knotgrass)']
# ['Aerva', 'lanata', '(Mountain', 'Knotgrass)']
# ['Aerva', 'lanata', '(Mountain', 'Knotgrass)']
# ['Aerva', 'lanata', '(Mountain', 'Knotgrass)']
# ['Aerva', 'lanata', '(Mountain', 'Knotgrass)']
# ['Aerva', 'lanata', '(Mountain', 'Knotgrass)']
# ['Aerva', 'lanata', '(Mountain', 'Knotgrass)']
# ['Aerva', 'lanata', '(Mountain', 'Knotgrass)']
# ['Aerva', 'lanata', '(Mountain', 'Knotgrass)']
# ['Aerva', 'lanata', '(Mountain', 'Knotgrass)']
# ['Aerva', 'lanata', '(Mountain', 'Knotgrass)']
# ['Aerva', 'lanata', '(Mountain', 'Knotgrass)']
# ['Aerva', 'lanata', '(Mountain', 'Knotgrass)']
# ['Aerva', 'lanata', '(Mountain', 'Knotgrass)']
# ['Aerva', 'lanata', '(Mountain', 'Knotgrass)']
# ['Aerva', 'lanata', '(Mountain', 'Knotgrass)']
# ['Mentha', 'piperita', '(Mint', 'Leaves)']
# ['Mentha', 'piperita', '(Mint', 'Leaves)']
# ['Mentha', 'piperita', '(Mint', 'Leaves)']
# ['Mentha', 'piperita', '(Mint', 'Leaves)']
# ['Mentha', 'piperita', '(Mint', 'Leaves)']
# ['Mentha', 'piperita', '(Mint', 'Leaves)']
# ['Mentha', 'piperita', '(Mint', 'Leaves)']
# ['Mentha', 'piperita', '(Mint', 'Leaves)']
# ['Mentha', 'piperita', '(Mint', 'Leaves)']
# ['Mentha', 'piperita', '(Mint', 'Leaves)']
# ['Mentha', 'piperita', '(Mint', 'Leaves)']
# ['Mentha', 'piperita', '(Mint', 'Leaves)']
# ['Mentha', 'piperita', '(Mint', 'Leaves)']
# ['Mentha', 'piperita', '(Mint', 'Leaves)']
# ['Mentha', 'piperita', '(Mint', 'Leaves)']
# ['Mentha', 'piperita', '(Mint', 'Leaves)']
# ['Mentha', 'piperita', '(Mint', 'Leaves)']
# ['Mentha', 'piperita', '(Mint', 'Leaves)']
# ['Mentha', 'piperita', '(Mint', 'Leaves)']
# ['Mentha', 'piperita', '(Mint', 'Leaves)']
# ['Mentha', 'piperita', '(Mint', 'Leaves)']
# ['Mentha', 'piperita', '(Mint', 'Leaves)']
# ['Argemone', 'mexicana', '(Mexican', 'Prickly', 'Poppy)']
# ['Argemone', 'mexicana', '(Mexican', 'Prickly', 'Poppy)']
# ['Argemone', 'mexicana', '(Mexican', 'Prickly', 'Poppy)']
# ['Argemone', 'mexicana', '(Mexican', 'Prickly', 'Poppy)']
# ['Argemone', 'mexicana', '(Mexican', 'Prickly', 'Poppy)']
# ['Argemone', 'mexicana', '(Mexican', 'Prickly', 'Poppy)']
# ['Argemone', 'mexicana', '(Mexican', 'Prickly', 'Poppy)']
# ['Argemone', 'mexicana', '(Mexican', 'Prickly', 'Poppy)']
# ['Argemone', 'mexicana', '(Mexican', 'Prickly', 'Poppy)']
# ['Argemone', 'mexicana', '(Mexican', 'Prickly', 'Poppy)']
# ['Argemone', 'mexicana', '(Mexican', 'Prickly', 'Poppy)']
# ['Argemone', 'mexicana', '(Mexican', 'Prickly', 'Poppy)']
# ['Argemone', 'mexicana', '(Mexican', 'Prickly', 'Poppy)']
# ['Argemone', 'mexicana', '(Mexican', 'Prickly', 'Poppy)']
# ['Argemone', 'mexicana', '(Mexican', 'Prickly', 'Poppy)']
# ['Argemone', 'mexicana', '(Mexican', 'Prickly', 'Poppy)']
# ['Argemone', 'mexicana', '(Mexican', 'Prickly', 'Poppy)']
# ['Argemone', 'mexicana', '(Mexican', 'Prickly', 'Poppy)']
# ['Argemone', 'mexicana', '(Mexican', 'Prickly', 'Poppy)']
# ['Argemone', 'mexicana', '(Mexican', 'Prickly', 'Poppy)']
# ['Argemone', 'mexicana', '(Mexican', 'Prickly', 'Poppy)']
# ['Coleus', 'amboinicus', '(Mexican', 'Mint)']
# ['Coleus', 'amboinicus', '(Mexican', 'Mint)']
# ['Coleus', 'amboinicus', '(Mexican', 'Mint)']
# ['Coleus', 'amboinicus', '(Mexican', 'Mint)']
# ['Coleus', 'amboinicus', '(Mexican', 'Mint)']
# ['Coleus', 'amboinicus', '(Mexican', 'Mint)']
# ['Coleus', 'amboinicus', '(Mexican', 'Mint)']
# ['Coleus', 'amboinicus', '(Mexican', 'Mint)']
# ['Coleus', 'amboinicus', '(Mexican', 'Mint)']
# ['Coleus', 'amboinicus', '(Mexican', 'Mint)']
# ['Coleus', 'amboinicus', '(Mexican', 'Mint)']
# ['Coleus', 'amboinicus', '(Mexican', 'Mint)']
# ['Coleus', 'amboinicus', '(Mexican', 'Mint)']
# ['Coleus', 'amboinicus', '(Mexican', 'Mint)']
# ['Coleus', 'amboinicus', '(Mexican', 'Mint)']
# ['Coleus', 'amboinicus', '(Mexican', 'Mint)']
# ['Coleus', 'amboinicus', '(Mexican', 'Mint)']
# ['Coleus', 'amboinicus', '(Mexican', 'Mint)']
# ['Coleus', 'amboinicus', '(Mexican', 'Mint)']
# ['Coleus', 'amboinicus', '(Mexican', 'Mint)']
# ['Coleus', 'amboinicus', '(Mexican', 'Mint)']
# ['Coleus', 'amboinicus', '(Mexican', 'Mint)']
# ['Basella', 'alba', '(Malabar', 'Spinach)']
# ['Basella', 'alba', '(Malabar', 'Spinach)']
# ['Basella', 'alba', '(Malabar', 'Spinach)']
# ['Basella', 'alba', '(Malabar', 'Spinach)']
# ['Basella', 'alba', '(Malabar', 'Spinach)']
# ['Basella', 'alba', '(Malabar', 'Spinach)']
# ['Basella', 'alba', '(Malabar', 'Spinach)']
# ['Basella', 'alba', '(Malabar', 'Spinach)']
# ['Basella', 'alba', '(Malabar', 'Spinach)']
# ['Basella', 'alba', '(Malabar', 'Spinach)']
# ['Basella', 'alba', '(Malabar', 'Spinach)']
# ['Basella', 'alba', '(Malabar', 'Spinach)']
# ['Basella', 'alba', '(Malabar', 'Spinach)']
# ['Basella', 'alba', '(Malabar', 'Spinach)']
# ['Basella', 'alba', '(Malabar', 'Spinach)']
# ['Anisomeles', 'indica', '(Malabar', 'Catmint)']
# ['Anisomeles', 'indica', '(Malabar', 'Catmint)']
# ['Anisomeles', 'indica', '(Malabar', 'Catmint)']
# ['Anisomeles', 'indica', '(Malabar', 'Catmint)']
# ['Anisomeles', 'indica', '(Malabar', 'Catmint)']
# ['Anisomeles', 'indica', '(Malabar', 'Catmint)']
# ['Anisomeles', 'indica', '(Malabar', 'Catmint)']
# ['Anisomeles', 'indica', '(Malabar', 'Catmint)']
# ['Cucumis', 'maderaspatanus', '(Madras', 'Pea', 'Pumpkin)']
# ['Cucumis', 'maderaspatanus', '(Madras', 'Pea', 'Pumpkin)']
# ['Cucumis', 'maderaspatanus', '(Madras', 'Pea', 'Pumpkin)']
# ['Cucumis', 'maderaspatanus', '(Madras', 'Pea', 'Pumpkin)']
# ['Cucumis', 'maderaspatanus', '(Madras', 'Pea', 'Pumpkin)']
# ['Cucumis', 'maderaspatanus', '(Madras', 'Pea', 'Pumpkin)']
# ['Cucumis', 'maderaspatanus', '(Madras', 'Pea', 'Pumpkin)']
# ['Cucumis', 'maderaspatanus', '(Madras', 'Pea', 'Pumpkin)']
# ['Cucumis', 'maderaspatanus', '(Madras', 'Pea', 'Pumpkin)']
# ['Cucumis', 'maderaspatanus', '(Madras', 'Pea', 'Pumpkin)']
# ['Cucumis', 'maderaspatanus', '(Madras', 'Pea', 'Pumpkin)']
# ['Cucumis', 'maderaspatanus', '(Madras', 'Pea', 'Pumpkin)']
# ['Cucumis', 'maderaspatanus', '(Madras', 'Pea', 'Pumpkin)']
# ['Cucumis', 'maderaspatanus', '(Madras', 'Pea', 'Pumpkin)']
# ['Cucumis', 'maderaspatanus', '(Madras', 'Pea', 'Pumpkin)']
# ['Cucumis', 'maderaspatanus', '(Madras', 'Pea', 'Pumpkin)']
# ['Cucumis', 'maderaspatanus', '(Madras', 'Pea', 'Pumpkin)']
# ['Cucumis', 'maderaspatanus', '(Madras', 'Pea', 'Pumpkin)']
# ['Cucumis', 'maderaspatanus', '(Madras', 'Pea', 'Pumpkin)']
# ['Cucumis', 'maderaspatanus', '(Madras', 'Pea', 'Pumpkin)']
# ['Cucumis', 'maderaspatanus', '(Madras', 'Pea', 'Pumpkin)']
# ['Cucumis', 'maderaspatanus', '(Madras', 'Pea', 'Pumpkin)']
# ['Cucumis', 'maderaspatanus', '(Madras', 'Pea', 'Pumpkin)']
# ['Cucumis', 'maderaspatanus', '(Madras', 'Pea', 'Pumpkin)']
# ['Cucumis', 'maderaspatanus', '(Madras', 'Pea', 'Pumpkin)']
# ['Cucumis', 'maderaspatanus', '(Madras', 'Pea', 'Pumpkin)']
# ['Cucumis', 'maderaspatanus', '(Madras', 'Pea', 'Pumpkin)']
# ['Cucumis', 'maderaspatanus', '(Madras', 'Pea', 'Pumpkin)']
# ['Cucumis', 'maderaspatanus', '(Madras', 'Pea', 'Pumpkin)']
# ['Cucumis', 'maderaspatanus', '(Madras', 'Pea', 'Pumpkin)']
# ['Cucumis', 'maderaspatanus', '(Madras', 'Pea', 'Pumpkin)']
# ['Cucumis', 'maderaspatanus', '(Madras', 'Pea', 'Pumpkin)']
# ['Cucumis', 'maderaspatanus', '(Madras', 'Pea', 'Pumpkin)']
# ['Cucumis', 'maderaspatanus', '(Madras', 'Pea', 'Pumpkin)']
# ['Cucumis', 'maderaspatanus', '(Madras', 'Pea', 'Pumpkin)']
# ['Cucumis', 'maderaspatanus', '(Madras', 'Pea', 'Pumpkin)']
# ['Cucumis', 'maderaspatanus', '(Madras', 'Pea', 'Pumpkin)']
# ['Cucumis', 'maderaspatanus', '(Madras', 'Pea', 'Pumpkin)']
# ['Catharanthus', 'roseus', '(Madagascar', 'Periwinkle)']
# ['Catharanthus', 'roseus', '(Madagascar', 'Periwinkle)']
# ['Catharanthus', 'roseus', '(Madagascar', 'Periwinkle)']
# ['Catharanthus', 'roseus', '(Madagascar', 'Periwinkle)']
# ['Catharanthus', 'roseus', '(Madagascar', 'Periwinkle)']
# ['Catharanthus', 'roseus', '(Madagascar', 'Periwinkle)']
# ['Catharanthus', 'roseus', '(Madagascar', 'Periwinkle)']
# ['Catharanthus', 'roseus', '(Madagascar', 'Periwinkle)']
# ['Catharanthus', 'roseus', '(Madagascar', 'Periwinkle)']
# ['Catharanthus', 'roseus', '(Madagascar', 'Periwinkle)']
# ['Catharanthus', 'roseus', '(Madagascar', 'Periwinkle)']
# ['Catharanthus', 'roseus', '(Madagascar', 'Periwinkle)']
# ['Catharanthus', 'roseus', '(Madagascar', 'Periwinkle)']
# ['Catharanthus', 'roseus', '(Madagascar', 'Periwinkle)']
# ['Catharanthus', 'roseus', '(Madagascar', 'Periwinkle)']
# ['Catharanthus', 'roseus', '(Madagascar', 'Periwinkle)']
# ['Catharanthus', 'roseus', '(Madagascar', 'Periwinkle)']
# ['Catharanthus', 'roseus', '(Madagascar', 'Periwinkle)']
# ['Catharanthus', 'roseus', '(Madagascar', 'Periwinkle)']
# ['Catharanthus', 'roseus', '(Madagascar', 'Periwinkle)']
# ['Catharanthus', 'roseus', '(Madagascar', 'Periwinkle)']
# ['Catharanthus', 'roseus', '(Madagascar', 'Periwinkle)']
# ['Catharanthus', 'roseus', '(Madagascar', 'Periwinkle)']
# ['Catharanthus', 'roseus', '(Madagascar', 'Periwinkle)']
# ['Catharanthus', 'roseus', '(Madagascar', 'Periwinkle)']
# ['Catharanthus', 'roseus', '(Madagascar', 'Periwinkle)']
# ['Catharanthus', 'roseus', '(Madagascar', 'Periwinkle)']
# ['Catharanthus', 'roseus', '(Madagascar', 'Periwinkle)']
# ['Catharanthus', 'roseus', '(Madagascar', 'Periwinkle)']
# ['Catharanthus', 'roseus', '(Madagascar', 'Periwinkle)']
# ['Catharanthus', 'roseus', '(Madagascar', 'Periwinkle)']
# ['Catharanthus', 'roseus', '(Madagascar', 'Periwinkle)']
# ['Catharanthus', 'roseus', '(Madagascar', 'Periwinkle)']
# ['Catharanthus', 'roseus', '(Madagascar', 'Periwinkle)']
# ['Catharanthus', 'roseus', '(Madagascar', 'Periwinkle)']
# ['Catharanthus', 'roseus', '(Madagascar', 'Periwinkle)']
# ['Pisonia', 'umbellifera', '(Lettuce', 'Tree)']
# ['Pisonia', 'umbellifera', '(Lettuce', 'Tree)']
# ['Pisonia', 'umbellifera', '(Lettuce', 'Tree)']
# ['Pisonia', 'umbellifera', '(Lettuce', 'Tree)']
# ['Pisonia', 'umbellifera', '(Lettuce', 'Tree)']
# ['Pisonia', 'umbellifera', '(Lettuce', 'Tree)']
# ['Pisonia', 'umbellifera', '(Lettuce', 'Tree)']
# ['Pisonia', 'umbellifera', '(Lettuce', 'Tree)']
# ['Pisonia', 'umbellifera', '(Lettuce', 'Tree)']
# ['Pisonia', 'umbellifera', '(Lettuce', 'Tree)']
# ['Pisonia', 'umbellifera', '(Lettuce', 'Tree)']
# ['Pisonia', 'umbellifera', '(Lettuce', 'Tree)']
# ['Pisonia', 'umbellifera', '(Lettuce', 'Tree)']
# ['Pisonia', 'umbellifera', '(Lettuce', 'Tree)']
# ['Pisonia', 'umbellifera', '(Lettuce', 'Tree)']
# ['Pisonia', 'umbellifera', '(Lettuce', 'Tree)']
# ['Pisonia', 'umbellifera', '(Lettuce', 'Tree)']
# ['Pisonia', 'umbellifera', '(Lettuce', 'Tree)']
# ['Pisonia', 'umbellifera', '(Lettuce', 'Tree)']
# ['Pisonia', 'umbellifera', '(Lettuce', 'Tree)']
# ['Pisonia', 'umbellifera', '(Lettuce', 'Tree)']
# ['Pisonia', 'umbellifera', '(Lettuce', 'Tree)']
# ['Pisonia', 'umbellifera', '(Lettuce', 'Tree)']
# ['Pisonia', 'umbellifera', '(Lettuce', 'Tree)']
# ['Pisonia', 'umbellifera', '(Lettuce', 'Tree)']
# ['Pisonia', 'umbellifera', '(Lettuce', 'Tree)']
# ['Pisonia', 'umbellifera', '(Lettuce', 'Tree)']
# ['Pisonia', 'umbellifera', '(Lettuce', 'Tree)']
# ['Pisonia', 'umbellifera', '(Lettuce', 'Tree)']
# ['Pisonia', 'umbellifera', '(Lettuce', 'Tree)']
# ['Pisonia', 'umbellifera', '(Lettuce', 'Tree)']
# ['Pisonia', 'umbellifera', '(Lettuce', 'Tree)']
# ['Pisonia', 'umbellifera', '(Lettuce', 'Tree)']
# ['Pisonia', 'umbellifera', '(Lettuce', 'Tree)']
# ['Pisonia', 'umbellifera', '(Lettuce', 'Tree)']
# ['Pisonia', 'umbellifera', '(Lettuce', 'Tree)']
# ['Pisonia', 'umbellifera', '(Lettuce', 'Tree)']
# ['Pisonia', 'umbellifera', '(Lettuce', 'Tree)']
# ['Pisonia', 'umbellifera', '(Lettuce', 'Tree)']
# ['Pisonia', 'umbellifera', '(Lettuce', 'Tree)']
# ['Pisonia', 'umbellifera', '(Lettuce', 'Tree)']
# ['Pisonia', 'umbellifera', '(Lettuce', 'Tree)']
# ['Pisonia', 'umbellifera', '(Lettuce', 'Tree)']
# ['Pisonia', 'umbellifera', '(Lettuce', 'Tree)']
# ['Pisonia', 'umbellifera', '(Lettuce', 'Tree)']
# ['Pisonia', 'umbellifera', '(Lettuce', 'Tree)']
# ['Pisonia', 'umbellifera', '(Lettuce', 'Tree)']
# ['Pisonia', 'umbellifera', '(Lettuce', 'Tree)']
# ['Pisonia', 'umbellifera', '(Lettuce', 'Tree)']
# ['Pisonia', 'umbellifera', '(Lettuce', 'Tree)']
# ['Pisonia', 'umbellifera', '(Lettuce', 'Tree)']
# ['Pisonia', 'umbellifera', '(Lettuce', 'Tree)']
# ['Pisonia', 'umbellifera', '(Lettuce', 'Tree)']
# ['Pisonia', 'umbellifera', '(Lettuce', 'Tree)']
# ['Pisonia', 'umbellifera', '(Lettuce', 'Tree)']
# ['Pisonia', 'umbellifera', '(Lettuce', 'Tree)']
# ['Land', 'Caltrops', '(Bindii)']
